# %% [markdown]
# # Service Pattern Boundaries: Ideal vs Worst GTFS Feed
#
# This notebook demonstrates how to generate two theoretical GTFS feeds:
# - **Ideal Service:** Every route operates every interval with a 5-minute headway.
# - **Worst Service:** Every route operates every interval with the maximum allowed headway (e.g., 120 minutes).
#
# I use these feeds to benchmark mode shares in MATSim under extreme service conditions. They give insights into the limits of the optimisation problem in terms of mode shift potential.

# %%
# Step 1: Import and Prepare GTFS Data

from transit_opt.preprocessing.prepare_gtfs import GTFSDataPreparator
from transit_opt.gtfs.gtfs import SolutionConverter
import numpy as np

# %% [markdown]
# ## Step 2: Configure Paths and Parameters
#
# Set up the GTFS file path, interval length, and allowed headways.
# Make sure 5 and the maximum value (e.g., 120) are included in `allowed_headways`.

# %%
gtfs_path = "../data/external/study_area_gtfs_bus.zip"  # Adjust if needed
interval_hours = 4  # 6 intervals per day
allowed_headways = [10, 15, 30, 60, 120]  # Must include 5 and max value

# %% [markdown]
# ## Step 3: Prepare Optimization Data
#
# Extract optimization data from the GTFS feed.
# This provides route and interval counts, and other metadata needed for solution construction.

# %%
preparator = GTFSDataPreparator(
    gtfs_path=gtfs_path,
    interval_hours=interval_hours,
    date=None,
    turnaround_buffer=1.15,
    max_round_trip_minutes=240.0,
    no_service_threshold_minutes=480.0,
)
opt_data = preparator.extract_optimization_data(allowed_headways)

n_routes = opt_data["n_routes"]
n_intervals = opt_data["n_intervals"]
# Out:
# Route 73302: Round-trip 317.4min exceeds limit (240.0min), filtered out
# Route 54721: Round-trip 366.8min exceeds limit (240.0min), filtered out
# Route 30922: Round-trip 247.2min exceeds limit (240.0min), filtered out
# Route 12490: Round-trip 416.3min exceeds limit (240.0min), filtered out
# Route 37599: Round-trip 355.3min exceeds limit (240.0min), filtered out
# Route 59129: Round-trip 396.7min exceeds limit (240.0min), filtered out
# Route 73828: Round-trip 258.8min exceeds limit (240.0min), filtered out
# Route 77159: Round-trip 954.5min exceeds limit (240.0min), filtered out
# Route 74948: Round-trip 1069.5min exceeds limit (240.0min), filtered out
# Route 57719: Round-trip 978.6min exceeds limit (240.0min), filtered out
# Route 31952: Round-trip 569.2min exceeds limit (240.0min), filtered out
# Route 77162: Round-trip 1207.5min exceeds limit (240.0min), filtered out
# Route 47558: Round-trip 770.5min exceeds limit (240.0min), filtered out
# ...

# %% [markdown]
# ## Step 4: Create Ideal and Worst Service Solution Matrices
#
# - **Ideal:** Fill the matrix with the index for 5-minute headway.
# - **Worst:** Fill the matrix with the index for the maximum allowed headway.

# %%
# Ideal service: 5-minute headway everywhere
ideal_headway = 10
ideal_idx = allowed_headways.index(ideal_headway)
ideal_solution_matrix = np.full((n_routes, n_intervals), ideal_idx, dtype=int)

# Worst service: max headway everywhere
worst_headway = max(allowed_headways)
worst_idx = allowed_headways.index(worst_headway)
worst_solution_matrix = np.full((n_routes, n_intervals), worst_idx, dtype=int)

# %% [markdown]
# ## Step 5: Convert, Validate, and Generate GTFS Feeds
#
# Use the `SolutionConverter` to validate each solution and generate the corresponding GTFS feed.

# %% [markdown]
# ### Ideal Service

# %%
converter = SolutionConverter(opt_data)

print("=== IDEAL SERVICE ===")
ideal_validation = converter.validate_solution(ideal_solution_matrix)
print("Valid:", ideal_validation["valid"])
print("Errors:", ideal_validation["errors"])
print("Coverage:", ideal_validation["statistics"]["service_percentage"])

ideal_headways_dict = converter.solution_to_headways(ideal_solution_matrix)
ideal_templates = converter.extract_route_templates()

ideal_gtfs_path = converter.build_complete_gtfs(
    ideal_headways_dict,
    ideal_templates,
    service_id="ideal_service",
    output_dir="output/ideal_service_gtfs",
    zip_output=True,
)
print("✅ Ideal GTFS feed created at:", ideal_gtfs_path)
# Out:
# === IDEAL SERVICE ===
# Valid: True
# Errors: []
# Coverage: 100.0
#    ⚠️  Route 50628, 00-04h (Dir 0): No trips found, using fallback
#    ⚠️  Route 50628, 00-04h (Dir 1): No trips found, using fallback
#    ⚠️  Route 50628, 00-04h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 08-12h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 12-16h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 16-20h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 0): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 1): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 08-12h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 12-16h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 16-20h (Dir 2): No trips found, using fallback
#    ⚠️  Route 58940, 00-04h (Dir 0): No trips found, using fallback
# ...

# %% [markdown]
# ### Worst Service

# %%
print("\n=== WORST SERVICE ===")
worst_validation = converter.validate_solution(worst_solution_matrix)
print("Valid:", worst_validation["valid"])
print("Errors:", worst_validation["errors"])
print("Coverage:", worst_validation["statistics"]["service_percentage"])

worst_headways_dict = converter.solution_to_headways(worst_solution_matrix)
worst_templates = converter.extract_route_templates()

worst_gtfs_path = converter.build_complete_gtfs(
    worst_headways_dict,
    worst_templates,
    service_id="worst_service",
    output_dir="output/worst_service_gtfs",
    zip_output=True,
)
print("✅ Worst GTFS feed created at:", worst_gtfs_path)
# Out:
# === WORST SERVICE ===
# Valid: True
# Errors: []
# Coverage: 100.0
#    ⚠️  Route 50628, 00-04h (Dir 0): No trips found, using fallback
#    ⚠️  Route 50628, 00-04h (Dir 1): No trips found, using fallback
#    ⚠️  Route 50628, 00-04h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 08-12h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 12-16h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 16-20h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 0): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 1): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 08-12h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 12-16h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 16-20h (Dir 2): No trips found, using fallback
#    ⚠️  Route 58940, 00-04h (Dir 0): No trips found, using fallback
# ...

# %% [markdown]
# ### Existing Service

# %% [markdown]
# #### Debug headsign / direction_id

# %%
# Analyze headsigns per route to validate the direction inference logic
# This helps us understand if using headsigns as a proxy for direction will lead to
# significantly more than 2 "directions" per route (e.g. if there are many unique headsigns)

if hasattr(preparator, "trips_df"):
    trips_df = preparator.trips_df
else:
    # Fallback if accessed differently
    trips_df = preparator.feed.trips

# Check if we have direction_id
has_direction_id = "direction_id" in trips_df.columns
print(f"Has direction_id column: {has_direction_id}")

if not has_direction_id:
    print("direction_id missing, using trip_headsign for analysis.")

    # Count unique headsigns per route
    # Filter out empty headsigns if necessary, though pandas nunique handles them
    headsign_counts = trips_df.groupby("route_id")["trip_headsign"].nunique()

    print(f"\nAverage headsigns per route: {headsign_counts.mean():.2f}")
    print(f"Median headsigns per route: {headsign_counts.median():.2f}")
    print(f"Max headsigns for a single route: {headsign_counts.max()}")

    # Show distribution
    print("\nHeadsign count distribution (Number of routes with X headsigns):")
    print(headsign_counts.value_counts().sort_index())

    # Show examples of routes with many headsigns
    high_count_routes = headsign_counts[headsign_counts > 2].index.tolist()
    if high_count_routes:
        print(f"\nExamples of routes with >2 headsigns (Total {len(high_count_routes)}):")
        for rid in high_count_routes[:5]:
            headsigns = trips_df[trips_df["route_id"] == rid]["trip_headsign"].unique()
            print(f"Route {rid}: {len(headsigns)} headsigns -> {list(headsigns)}")
else:
    print("Using existing direction_id column.")
    dir_counts = trips_df.groupby("route_id")["direction_id"].nunique()
    print(f"Average directions per route: {dir_counts.mean():.2f}")
# Out:
# Has direction_id column: False
# direction_id missing, using trip_headsign for analysis.
#
# Average headsigns per route: 2.58
# Median headsigns per route: 2.00
# Max headsigns for a single route: 8
#
# Headsign count distribution (Number of routes with X headsigns):
# trip_headsign
# 1     13
# 2    102
# 3     40
# 4     23
# 5      4
# 6      3
# 7      1
# 8      1
# Name: count, dtype: int64
#
# Examples of routes with >2 headsigns (Total 72):
# Route 11855: 3 headsigns -> ['Wakefield City Centre', 'Bradford City Centre', 'Morley']
# Route 11878: 4 headsigns -> ['Castleford', 'Leeds City Centre', 'Garforth', 'Kippax']
# Route 11963: 5 headsigns -> ['Huddersfield Town Centre', 'Dewsbury', 'Leeds City Centre', 'Tingley', 'Mirfield']
# Route 11986: 3 headsigns -> ['Wakefield City Centre', 'Leeds City Centre', 'Sandal']
# Route 11989: 3 headsigns -> ['Leeds City Centre', 'Brighouse', 'Cleckheaton']

# %%
# # Reload the gtfs module to pick up the latest changes
# import importlib
# import transit_opt.gtfs.gtfs

# importlib.reload(transit_opt.gtfs.gtfs)
# from transit_opt.gtfs.gtfs import SolutionConverter

# # Now rerun the conversion (Assuming opt_data, etc. are already loaded in memory)
# print("=== Re-running Ideal Service Generation with Updated Code ===")

# # Create converter with current opt_data
# converter = SolutionConverter(opt_data)

# # Re-generate Ideal GTFS
# ideal_headways_dict = converter.solution_to_headways(ideal_solution_matrix)
# ideal_templates = converter.extract_route_templates()

# ideal_gtfs_path = converter.build_complete_gtfs(
#     ideal_headways_dict,
#     ideal_templates,
#     service_id="ideal_service",
#     output_dir="output/ideal_service_gtfs_v2",
#     zip_output=True,
# )
# print("✅ Ideal GTFS feed created at:", ideal_gtfs_path)

# # Verify the output trips file has unique IDs and correct headsigns
# import pandas as pd
# import zipfile

# with zipfile.ZipFile(ideal_gtfs_path, "r") as z:
#     with z.open("trips.txt") as f:
#         df_trips = pd.read_csv(f)

# print("\nSample of generated trips (checking ID format and headsigns):")
# print(df_trips[["trip_id", "trip_headsign", "direction_id"]].head(10))

# # Check for duplicates in trip_id
# duplicates = df_trips[df_trips.duplicated("trip_id")]
# if not duplicates.empty:
#     print(f"\n❌ Found {len(duplicates)} duplicate trip_ids!")
#     print(duplicates[["trip_id", "direction_id"]].head())
# else:
#     print("\n✅ No duplicate trip_ids found.")

# # analyzing headsigns per direction
# print("\nUnique headsigns per direction (Global):")
# print(df_trips.groupby("direction_id")["trip_headsign"].unique())

# print("\nSpecific analysis for Route 50627:")
# route_50627 = df_trips[df_trips["route_id"] == "50627"]  # Ensure string if IDs are strings
# if route_50627.empty:
#     route_50627 = df_trips[df_trips["route_id"] == 50627]  # Try integer

# print(route_50627.groupby("direction_id")["trip_headsign"].unique())

# %% [markdown]
# #### Process base service

# %%
print("\n=== BASE SERVICE (FILTERED) ===")
# The initial_solution in opt_data represents the base service mapped to nearest allowed headways
base_solution_matrix = opt_data["initial_solution"]

base_validation = converter.validate_solution(base_solution_matrix)
print("Valid:", base_validation["valid"])
print("Errors:", base_validation["errors"])
print("Coverage:", base_validation["statistics"]["service_percentage"])

base_headways_dict = converter.solution_to_headways(base_solution_matrix)
base_templates = converter.extract_route_templates()

base_gtfs_path = converter.build_complete_gtfs(
    base_headways_dict,
    base_templates,
    service_id="base_service",
    output_dir="output/basic/base_gtfs",  # Creates output/basic/base_gtfs.zip
    zip_output=True,
)
print("✅ Base GTFS feed created at:", base_gtfs_path)
# Out:
# === BASE SERVICE (FILTERED) ===
# Valid: True
# Errors: []
# Coverage: 55.78231292517006
#    ⚠️  Route 50628, 00-04h (Dir 0): No trips found, using fallback
#    ⚠️  Route 50628, 00-04h (Dir 1): No trips found, using fallback
#    ⚠️  Route 50628, 00-04h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 08-12h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 12-16h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50628, 16-20h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 0): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 1): No trips found, using fallback
#    ⚠️  Route 50629, 00-04h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 08-12h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 12-16h (Dir 2): No trips found, using fallback
#    ⚠️  Route 50629, 16-20h (Dir 2): No trips found, using fallback
#    ⚠️  Route 58940, 00-04h (Dir 0): No trips found, using fallback
# ...
