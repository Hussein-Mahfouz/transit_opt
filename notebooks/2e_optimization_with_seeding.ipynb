# %% [markdown]
# # Seeding PSO Optimization with Custom Initial Populations
#
# This notebook demonstrates functionality for seeding a Particle Swarm Optimization (PSO) algorithm with custom initial populations. It can be useful when you have good candidate solutions and want to guide the optimization process.
#
# Some basics about PSO and it's implementation in PYMOO:
# - If you do not pass a custom initial population, PYMOO will generate one using a sampling method. The default method is Latin Hypercube Sampling (LHS).
# - If you want to use a custom initial population, you can pass it directly using the sampling parameter (see documentation: https://pymoo.org/algorithms/soo/pso.html).
# - This notebook shows how to prepare and pass custom populations
#
#
#
# #### Step 1: Define initial solutions
#
# We provide two ways to create a custom initial population:
# 1. `from_data`: This is based on the initial solution (in this case, it is the GTFS feed (and DRT) read by `extract_optimization_data` / `extract_optimization_data_with_drt`)
# 2. List: A list of solutions. This is useful if you have good solutions from a previous run. We provide a utility function `extract_multiple_gtfs_solutions` to read in these solutions from disk. It is compatible with solutions saved in `3_write_solutions_to_file.ipynb`
#
# #### Step 2: Add complementary solutions to match the population size
#
# Let's say you want to run PSO with a population (pop_size) of 20. If you want to use `sampling`, then the size of the custom population must match the `pop_size` of the algorithm.
# It is very likely (and encouraged!!!) for your custom initial population to have fewer solutions than the desired `pop_size`. The remianing solution are added using a combination of Gaussian pertubabtion (noise) and LHS.
#
# - Gaussian pertubation means that we take an existing solution and add some noise to it. This is useful when you have a good solution and want to explore the nearby solution space.
# - LHS is used to fill in any remaining slots in the population. This ensures diversity in the population.
#
# You have to decide
# - Proportion of remaining solutions to be filled using Gaussian pertubation vs LHS.
# - Standard deviation of the Gaussian noise. If standard deviation is 1, then you should expect that ~68% of the pertubed solutions will be within 1 unit of the original solution. In our case, we use index values [1, 2, ..., n] to represent discrete choices (headway or drt fleet size), so I reccomend a standard deviation that makes sense relative to the range of index values.
#
# The `PopulationBuilder` class then builds a complete population of the desired size.

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from pathlib import Path
import json
from typing import Dict, Any, List
import logging

# Add src to path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

logging.basicConfig(level=logging.INFO)

# %%
from transit_opt.optimisation.spatial.boundaries import StudyAreaBoundary

# Load boundary for creating problem later
boundary_gdf = gpd.read_file("../data/external/boundaries/study_area_boundary.geojson")
study_boundary = StudyAreaBoundary(
    boundary_gdf=boundary_gdf,
    crs="EPSG:3857",
    buffer_km=2.0
)
# Out:
# ✅ Validated metric CRS: EPSG:3857
# 🔄 Converting boundary CRS: EPSG:4326 → EPSG:3857
# 📏 Applied 2.0km buffer
# ✅ Study area set: 1 polygon(s) in EPSG:3857

# %% [markdown]
# # How to load in solutions from disk
#
# Here we show two different ways to load in solutions from disk.
# 1. Load in a single solution: This is the standard way used in other notebooks. We just load in an existing GTFS file
# 2. Load in multiple solutions: This is useful when you have a set of good solutions from a previous run. We use `extract_multiple_gtfs_solutions` which can extract gtfs zip files, their corresponding drt json files, and link them to create dsolutions in the correct format

# %% [markdown]
# ## Loading in a single base solution with DRT

# %%
from transit_opt.preprocessing.prepare_gtfs import GTFSDataPreparator

# Set up paths
gtfs_path = '../data/external/study_area_gtfs_bus.zip'

print(f"\n📂 GTFS data path: {gtfs_path}")

# Define DRT configuration (matching your provided config)
drt_config = {
    'enabled': True,
    'target_crs': 'EPSG:3857',
    'default_drt_speed_kmh': 25.0,
    'zones': [
        {
            'zone_id': 'drt_ne',
            'service_area_path': '../data/external/drt/drt_ne.shp',
            'allowed_fleet_sizes': [0, 10, 25, 50, 100],
            'zone_name': 'Leeds NE DRT',
            'drt_speed_kmh': 20.0
        },
        {
            'zone_id': 'drt_nw',
            'service_area_path': '../data/external/drt/drt_nw.shp',
            'allowed_fleet_sizes': [0, 15, 30, 60, 120],
            'zone_name': 'Leeds NW DRT'
        }
    ]
}

print("\n🚁 DRT Configuration:")
print(f"   Zones: {len(drt_config['zones'])}")
for zone in drt_config['zones']:
    print(f"   • {zone['zone_name']}: {zone['allowed_fleet_sizes']}")

# Create preparator and extract PT+DRT optimization data
print("\n🔧 Extracting PT+DRT optimization data...")

preparator = GTFSDataPreparator(
    gtfs_path=gtfs_path,
    interval_hours=6,
    log_level="WARNING"
)

allowed_headways = [10, 15, 30, 60, 120, 240]

# Extract optimization data WITH DRT
opt_data = preparator.extract_optimization_data_with_drt(
    allowed_headways=allowed_headways,
    drt_config=drt_config
)

# Show initial solution structure
print(f"\n📋 Initial Solution Structure:")
print(f"   Format: Flat array for PSO")
print(f"   Shape: {opt_data['initial_solution'].shape}")
print(f"   Contains: PT headway indices + DRT fleet size indices")
print(f"   First 10 values: {opt_data['initial_solution'][:10]}")
print(f"   Last 10 values: {opt_data['initial_solution'][-10:]}")


print("\n✅ Section 1 Complete: Base solution loaded from GTFS with DRT")
# Out:
# 📂 GTFS data path: ../data/external/study_area_gtfs_bus.zip
#
# 🚁 DRT Configuration:
#    Zones: 2
#    • Leeds NE DRT: [0, 10, 25, 50, 100]
#    • Leeds NW DRT: [0, 15, 30, 60, 120]
#
# 🔧 Extracting PT+DRT optimization data...
# 🔧 EXTRACTING OPTIMIZATION DATA WITH DRT SUPPORT:
# 2025-10-29 15:42:53,111 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 73302: Round-trip 317.4min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 73302: Round-trip 317.4min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:53,146 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 54721: Round-trip 366.8min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 54721: Round-trip 366.8min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:54,521 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 30922: Round-trip 247.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 30922: Round-trip 247.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:55,177 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 12490: Round-trip 416.3min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 12490: Round-trip 416.3min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:55,239 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 37599: Round-trip 355.3min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 37599: Round-trip 355.3min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:57,000 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 59129: Round-trip 396.7min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 59129: Round-trip 396.7min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:59,779 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 73828: Round-trip 258.8min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 73828: Round-trip 258.8min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:59,823 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 77159: Round-trip 954.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 77159: Round-trip 954.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:59,858 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 74948: Round-trip 1069.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 74948: Round-trip 1069.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:59,892 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 57719: Round-trip 978.6min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 57719: Round-trip 978.6min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:59,925 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 31952: Round-trip 569.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 31952: Round-trip 569.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:42:59,962 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 77162: Round-trip 1207.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 77162: Round-trip 1207.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,011 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 47558: Round-trip 770.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 47558: Round-trip 770.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,052 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 73397: Round-trip 586.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 73397: Round-trip 586.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,107 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 63868: Round-trip 494.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 63868: Round-trip 494.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,140 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 72083: Round-trip 1248.9min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 72083: Round-trip 1248.9min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,182 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 74356: Round-trip 437.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 74356: Round-trip 437.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,224 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 16835: Round-trip 1219.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 16835: Round-trip 1219.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,262 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 19472: Round-trip 460.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 19472: Round-trip 460.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,297 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 72084: Round-trip 678.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 72084: Round-trip 678.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,332 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 76603: Round-trip 529.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 76603: Round-trip 529.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,398 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 33496: Round-trip 856.7min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 33496: Round-trip 856.7min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,442 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 31956: Round-trip 1075.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 31956: Round-trip 1075.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,476 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 72085: Round-trip 523.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 72085: Round-trip 523.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,526 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 124: Round-trip 736.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 124: Round-trip 736.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,580 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 38189: Round-trip 828.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 38189: Round-trip 828.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,636 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 72342: Round-trip 494.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 72342: Round-trip 494.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,671 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 31957: Round-trip 960.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 31957: Round-trip 960.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,707 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 13406: Round-trip 437.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 13406: Round-trip 437.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,740 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 39851: Round-trip 609.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 39851: Round-trip 609.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,802 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 16836: Round-trip 586.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 16836: Round-trip 586.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,840 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 72090: Round-trip 270.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 72090: Round-trip 270.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,880 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 18680: Round-trip 396.7min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 18680: Round-trip 396.7min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,921 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 74362: Round-trip 460.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 74362: Round-trip 460.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,953 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 67719: Round-trip 845.2min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 67719: Round-trip 845.2min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:00,987 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 57312: Round-trip 552.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 57312: Round-trip 552.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:01,021 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 76607: Round-trip 1230.5min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 76607: Round-trip 1230.5min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:01,523 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 54718: Round-trip 560.0min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 54718: Round-trip 560.0min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:02,513 - transit_opt.preprocessing.prepare_gtfs - WARNING - Route 11963: Round-trip 259.9min exceeds limit (240.0min), filtered out
# WARNING:transit_opt.preprocessing.prepare_gtfs:Route 11963: Round-trip 259.9min exceeds limit (240.0min), filtered out
# 2025-10-29 15:43:03,924 - transit_opt.preprocessing.prepare_gtfs - WARNING - Filtered out 39 routes (excessive round-trip time)
# WARNING:transit_opt.preprocessing.prepare_gtfs:Filtered out 39 routes (excessive round-trip time)
# 2025-10-29 15:43:03,925 - transit_opt.preprocessing.prepare_gtfs - WARNING - Failed to process 1 routes (no valid data)
# WARNING:transit_opt.preprocessing.prepare_gtfs:Failed to process 1 routes (no valid data)
# 2025-10-29 15:43:03,928 - transit_opt.preprocessing.prepare_gtfs - WARNING - Found 16 cells with >10min mapping difference
# WARNING:transit_opt.preprocessing.prepare_gtfs:Found 16 cells with >10min mapping difference
# 2025-10-29 15:43:03,933 - transit_opt.preprocessing.prepare_gtfs - WARNING - Large discrepancy between raw and discretized fleet calculations!
# WARNING:transit_opt.preprocessing.prepare_gtfs:Large discrepancy between raw and discretized fleet calculations!
#    ✅ Base PT data extracted: 147 routes, 4 intervals
#    🚁 Adding DRT configuration...
#    🔍 Validating DRT configuration...
#    ✅ DRT configuration valid: 2 zones
#       Target CRS: EPSG:3857
#    🗺️ Loading DRT spatial layers...
#       Target CRS: EPSG:3857
#       Loading zone 1: drt_ne
#          Path: ../data/external/drt/drt_ne.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#          ✅ Loaded: 474.95 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 10, 25, 50, 100]
#       Loading zone 2: drt_nw
#          Path: ../data/external/drt/drt_nw.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#    DRT Zone drt_nw: 151.69 km², speed 25.0 km/h
#          ✅ Loaded: 151.69 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 15, 30, 60, 120]
#    ✅ All DRT spatial layers loaded successfully
#       Total DRT service area: 626.64 km²
#    🔧 Creating combined PT+DRT initial solution...
#       Zone drt_ne: Initial fleet choice 0 (0 vehicles)
#       Zone drt_nw: Initial fleet choice 0 (0 vehicles)
#    ✅ Combined initial solution created:
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#    🚁 DRT integration complete:
#       DRT zones: 2
#       Max fleet choices per zone: 5
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#       Total DRT service area: 626.64 km²
#
# 📋 Initial Solution Structure:
#    Format: Flat array for PSO
#    Shape: (596,)
#    Contains: PT headway indices + DRT fleet size indices
#    First 10 values: [3 0 0 1 1 1 1 1 6 1]
#    Last 10 values: [3 3 0 0 0 0 0 0 0 0]
#
# ✅ Section 1 Complete: Base solution loaded from GTFS with DRT

# %% [markdown]
# ### Loading multiple solutions from disk
#
# If you have multiple good solutions from a previous run, you can load them in using the `extract_multiple_gtfs_solutions` function. Here I load in solutions that I created using code from `2d_optimization_joint_PT_DRT.ipynb`. the code below shows the directory structure, and the gtfs zip files and drt files inside it
#
# You can see code for writing solutions to disk in `3_write_solutions_to_file.ipynb`

# %%
# Set up paths to saved solutions
solutions_dir = Path("output/combined_pt_drt_solutions")

print(f"\n📁 Solutions directory: {solutions_dir}")

# Check what solution files exist
drt_files = sorted(solutions_dir.glob("*_drt.json"))
gtfs_files = sorted(solutions_dir.glob("*_gtfs.zip"))

print(f"\n📋 Available solution files:")
print(f"   DRT files: {[f.name for f in drt_files]}")
print(f"   GTFS files: {[f.name for f in gtfs_files]}")

    
# Use extract_multiple_gtfs_solutions to load all solutions at once
print("\n🔄 Loading multiple solutions using extract_multiple_gtfs_solutions()...")
    
opt_data_list = preparator.extract_multiple_gtfs_solutions(
    gtfs_paths=[
        str(solutions_dir / 'combined_solution_01_gtfs.zip'),
        str(solutions_dir / 'combined_solution_02_gtfs.zip'),
        str(solutions_dir / 'combined_solution_03_gtfs.zip')
    ],
    allowed_headways=allowed_headways,
    drt_config=drt_config,
    drt_solution_paths=[
        str(solutions_dir / 'combined_solution_01_drt.json'),
        str(solutions_dir / 'combined_solution_02_drt.json'),
        str(solutions_dir / 'combined_solution_03_drt.json')
    ]
)
    
print(f"\n✅ LOADED {len(opt_data_list)} COMPLETE SOLUTIONS:")
for i, data in enumerate(opt_data_list, 1):
    print(f"\n   Solution {i}:")
    print(f"      PT variables: {data['pt_decision_variables']}")
    print(f"      DRT variables: {data['drt_decision_variables']}")
    print(f"      Initial solution shape: {data['initial_solution'].shape}")
    print(f"      Source GTFS: {data['metadata']['source_gtfs_path']}")
    print(f"      Source DRT: {data['metadata']['source_drt_path']}")

# Extract just the initial solutions (flat arrays)
flat_solutions_from_files = [data['initial_solution'] for data in opt_data_list]

print(f"\n📦 Extracted {len(flat_solutions_from_files)} flat solution arrays")
print(f"   These are ready to be used as base solutions for seeding PSO")
# Out:
# 📁 Solutions directory: output/combined_pt_drt_solutions
#
# 📋 Available solution files:
#    DRT files: ['combined_solution_01_drt.json', 'combined_solution_02_drt.json', 'combined_solution_03_drt.json']
#    GTFS files: ['combined_solution_01_gtfs.zip', 'combined_solution_02_gtfs.zip', 'combined_solution_03_gtfs.zip']
#
# 🔄 Loading multiple solutions using extract_multiple_gtfs_solutions()...
# Processing GTFS feed 1/3: output/combined_pt_drt_solutions/combined_solution_01_gtfs.zip
# 🔧 EXTRACTING OPTIMIZATION DATA WITH DRT SUPPORT:
#    ✅ Base PT data extracted: 147 routes, 4 intervals
#    🚁 Adding DRT configuration...
#    🔍 Validating DRT configuration...
#    ✅ DRT configuration valid: 2 zones
#       Target CRS: EPSG:3857
#    🗺️ Loading DRT spatial layers...
#       Target CRS: EPSG:3857
#       Loading zone 1: drt_ne
#          Path: ../data/external/drt/drt_ne.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#          ✅ Loaded: 474.95 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 10, 25, 50, 100]
#       Loading zone 2: drt_nw
#          Path: ../data/external/drt/drt_nw.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#    DRT Zone drt_nw: 151.69 km², speed 25.0 km/h
#          ✅ Loaded: 151.69 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 15, 30, 60, 120]
#    ✅ All DRT spatial layers loaded successfully
#       Total DRT service area: 626.64 km²
#    🔧 Creating combined PT+DRT initial solution...
#       Zone drt_ne: Initial fleet choice 0 (0 vehicles)
#       Zone drt_nw: Initial fleet choice 0 (0 vehicles)
#    ✅ Combined initial solution created:
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#    🚁 DRT integration complete:
#       DRT zones: 2
#       Max fleet choices per zone: 5
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#       Total DRT service area: 626.64 km²
#   📊 Base optimization data: 147 routes, 596 variables
#   🚁 Loading DRT solution from: output/combined_pt_drt_solutions/combined_solution_01_drt.json
#     Zone drt_ne 00-06h: 25 vehicles (idx 2)
#     Zone drt_ne 06-12h: 0 vehicles (idx 0)
#     Zone drt_ne 12-18h: 100 vehicles (idx 4)
#     Zone drt_ne 18-24h: 50 vehicles (idx 3)
#     Zone drt_nw 00-06h: 15 vehicles (idx 1)
#     Zone drt_nw 06-12h: 0 vehicles (idx 0)
#     Zone drt_nw 12-18h: 0 vehicles (idx 0)
#     Zone drt_nw 18-24h: 15 vehicles (idx 1)
# ✅ Loaded DRT solution from: output/combined_pt_drt_solutions/combined_solution_01_drt.json
#    Zones loaded: 2/2
#   📈 Loaded DRT matrix: (2, 4) (zones × intervals)
#     🔧 Updated DRT portion: indices 588:596
#     📊 DRT values: [2, 0, 4, 3, 1, 0, 0, 1]
#   ✅ Applied DRT solution to optimization data
# Processing GTFS feed 2/3: output/combined_pt_drt_solutions/combined_solution_02_gtfs.zip
# 🔧 EXTRACTING OPTIMIZATION DATA WITH DRT SUPPORT:
#    ✅ Base PT data extracted: 147 routes, 4 intervals
#    🚁 Adding DRT configuration...
#    🔍 Validating DRT configuration...
#    ✅ DRT configuration valid: 2 zones
#       Target CRS: EPSG:3857
#    🗺️ Loading DRT spatial layers...
#       Target CRS: EPSG:3857
#       Loading zone 1: drt_ne
#          Path: ../data/external/drt/drt_ne.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#          ✅ Loaded: 474.95 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 10, 25, 50, 100]
#       Loading zone 2: drt_nw
#          Path: ../data/external/drt/drt_nw.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#    DRT Zone drt_nw: 151.69 km², speed 25.0 km/h
#          ✅ Loaded: 151.69 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 15, 30, 60, 120]
#    ✅ All DRT spatial layers loaded successfully
#       Total DRT service area: 626.64 km²
#    🔧 Creating combined PT+DRT initial solution...
#       Zone drt_ne: Initial fleet choice 0 (0 vehicles)
#       Zone drt_nw: Initial fleet choice 0 (0 vehicles)
#    ✅ Combined initial solution created:
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#    🚁 DRT integration complete:
#       DRT zones: 2
#       Max fleet choices per zone: 5
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#       Total DRT service area: 626.64 km²
#   📊 Base optimization data: 147 routes, 596 variables
#   🚁 Loading DRT solution from: output/combined_pt_drt_solutions/combined_solution_02_drt.json
#     Zone drt_ne 00-06h: 25 vehicles (idx 2)
#     Zone drt_ne 06-12h: 0 vehicles (idx 0)
#     Zone drt_ne 12-18h: 50 vehicles (idx 3)
#     Zone drt_ne 18-24h: 50 vehicles (idx 3)
#     Zone drt_nw 00-06h: 15 vehicles (idx 1)
#     Zone drt_nw 06-12h: 0 vehicles (idx 0)
#     Zone drt_nw 12-18h: 0 vehicles (idx 0)
#     Zone drt_nw 18-24h: 15 vehicles (idx 1)
# ✅ Loaded DRT solution from: output/combined_pt_drt_solutions/combined_solution_02_drt.json
#    Zones loaded: 2/2
#   📈 Loaded DRT matrix: (2, 4) (zones × intervals)
#     🔧 Updated DRT portion: indices 588:596
#     📊 DRT values: [2, 0, 3, 3, 1, 0, 0, 1]
#   ✅ Applied DRT solution to optimization data
# Processing GTFS feed 3/3: output/combined_pt_drt_solutions/combined_solution_03_gtfs.zip
# 🔧 EXTRACTING OPTIMIZATION DATA WITH DRT SUPPORT:
#    ✅ Base PT data extracted: 147 routes, 4 intervals
#    🚁 Adding DRT configuration...
#    🔍 Validating DRT configuration...
#    ✅ DRT configuration valid: 2 zones
#       Target CRS: EPSG:3857
#    🗺️ Loading DRT spatial layers...
#       Target CRS: EPSG:3857
#       Loading zone 1: drt_ne
#          Path: ../data/external/drt/drt_ne.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#          ✅ Loaded: 474.95 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 10, 25, 50, 100]
#       Loading zone 2: drt_nw
#          Path: ../data/external/drt/drt_nw.shp
#          Original CRS: EPSG:3857
#          🔄 Converting: EPSG:3857 → EPSG:3857
#    DRT Zone drt_ne: 474.95 km², speed 20.0 km/h
#    DRT Zone drt_nw: 151.69 km², speed 25.0 km/h
#          ✅ Loaded: 151.69 km² service area
#             CRS: EPSG:3857
#             Fleet choices: [0, 15, 30, 60, 120]
#    ✅ All DRT spatial layers loaded successfully
#       Total DRT service area: 626.64 km²
#    🔧 Creating combined PT+DRT initial solution...
#       Zone drt_ne: Initial fleet choice 0 (0 vehicles)
#       Zone drt_nw: Initial fleet choice 0 (0 vehicles)
#    ✅ Combined initial solution created:
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#    🚁 DRT integration complete:
#       DRT zones: 2
#       Max fleet choices per zone: 5
#       PT variables: 588
#       DRT variables: 8
#       Total variables: 596
#       Total DRT service area: 626.64 km²
#   📊 Base optimization data: 147 routes, 596 variables
#   🚁 Loading DRT solution from: output/combined_pt_drt_solutions/combined_solution_03_drt.json
#     Zone drt_ne 00-06h: 25 vehicles (idx 2)
#     Zone drt_ne 06-12h: 0 vehicles (idx 0)
#     Zone drt_ne 12-18h: 100 vehicles (idx 4)
#     Zone drt_ne 18-24h: 50 vehicles (idx 3)
#     Zone drt_nw 00-06h: 15 vehicles (idx 1)
#     Zone drt_nw 06-12h: 0 vehicles (idx 0)
#     Zone drt_nw 12-18h: 0 vehicles (idx 0)
#     Zone drt_nw 18-24h: 15 vehicles (idx 1)
# ✅ Loaded DRT solution from: output/combined_pt_drt_solutions/combined_solution_03_drt.json
#    Zones loaded: 2/2
#   📈 Loaded DRT matrix: (2, 4) (zones × intervals)
#     🔧 Updated DRT portion: indices 588:596
#     📊 DRT values: [2, 0, 4, 3, 1, 0, 0, 1]
#   ✅ Applied DRT solution to optimization data
# ✅ Extracted 3 optimization data structures
#
# ✅ LOADED 3 COMPLETE SOLUTIONS:
#
#    Solution 1:
#       PT variables: 588
#       DRT variables: 8
#       Initial solution shape: (596,)
#       Source GTFS: output/combined_pt_drt_solutions/combined_solution_01_gtfs.zip
#       Source DRT: output/combined_pt_drt_solutions/combined_solution_01_drt.json
#
#    Solution 2:
#       PT variables: 588
#       DRT variables: 8
#       Initial solution shape: (596,)
#       Source GTFS: output/combined_pt_drt_solutions/combined_solution_02_gtfs.zip
#       Source DRT: output/combined_pt_drt_solutions/combined_solution_02_drt.json
#
#    Solution 3:
#       PT variables: 588
#       DRT variables: 8
#       Initial solution shape: (596,)
#       Source GTFS: output/combined_pt_drt_solutions/combined_solution_03_gtfs.zip
#       Source DRT: output/combined_pt_drt_solutions/combined_solution_03_drt.json
#
# 📦 Extracted 3 flat solution arrays
#    These are ready to be used as base solutions for seeding PSO

# %% [markdown]
# # Using loaded solutions to build a complete population for seeding
#
# As mentioned previously, we want to ensure that we pass a complete population of size `pop_size` to the `sampling` parameter in PYMOO. Why? From the documentation, PYMOO will not generate any additional solutions if the size of the custom population passed to `sampling` is less than `pop_size`, so the `pop_size` you define is not going to be the `pop_size` used in the PSO run
#
# Here we show how to use the loaded solutions to build a complete population using the `PopulationBuilder` class. The basic idea of the class is:
# - You have N initial solutions. You need an additional `pop_size - N` solutions to complete the population
# - You decide the proportion of the remaining solutions you want to create using Gaussian pertubation of existing solutions. The remaining solutions are creating using LHS
# - You also decide the standard deviation of the Gaussian noise
# - The class then builds a complete population of size `pop_size`
#
# LHS() is a very effective way to sample the solution space. Gaussian pertubation is useful when you have good solutions and want to explore the nearby solution space. I recommend keeping the proportion of Gaussian pertubation low (e.g., 20-30%) to ensure diversity in the population.

# %%
from transit_opt.optimisation.utils.solution_loader import SolutionLoader
from transit_opt.optimisation.utils.population_builder import PopulationBuilder
from transit_opt.optimisation.objectives.service_coverage import HexagonalCoverageObjective
from transit_opt.optimisation.problems.transit_problem import TransitOptimizationProblem

print("\n📚 UNDERSTANDING THE SEEDING WORKFLOW:")
print("   1. Load base solutions (from GTFS or previous runs)")
print("   2. Use SolutionLoader to validate and format solutions")
print("   3. Use PopulationBuilder to create PSO initial population")
print("   4. Pass population to PSO via configuration")

# Create problem for population building
print("\n🔧 Creating optimization problem...")

coverage_objective = HexagonalCoverageObjective(
    optimization_data=opt_data,
    spatial_resolution_km=2.0,
    crs="EPSG:3857",
    boundary=study_boundary,
    time_aggregation="average"
)

problem = TransitOptimizationProblem(
    optimization_data=opt_data,
    objective=coverage_objective
)

print(f"✅ Problem created:")
print(f"   Variables: {problem.n_var}")
print(f"   DRT enabled: {problem.drt_enabled}")

# Initialize loaders and builders
solution_loader = SolutionLoader()
population_builder = PopulationBuilder(solution_loader)

print("\n" + "-"*70)
print("STRATEGY A: SEEDING FROM BASE GTFS DATA ('from_data')")
print("-"*70)

print("\n📋 The 'from_data' strategy:")
print("   • Uses opt_data['initial_solution'] as the base")
print("   • Creates variations using Gaussian perturbations")
print("   • Fills remaining slots with Latin Hypercube Sampling (LHS)")

print("\n🎯 KEY PARAMETER: frac_gaussian_pert")
print("   Controls the mix of perturbations vs random exploration:")
print("   • frac_gaussian_pert = 0.7 → 70% Gaussian + 30% LHS")
print("   • Higher value = more exploration near base solution")
print("   • Lower value = more random exploration")

# Build population from base GTFS data
pop_size = 30
population_from_data = population_builder.build_initial_population(
    problem=problem,
    pop_size=pop_size,
    optimization_data=opt_data,
    base_solutions='from_data',  # Use base GTFS solution
    frac_gaussian_pert=0.7,      # 70% perturbations, 30% LHS
    gaussian_sigma=0.5,          # Moderate perturbation strength
    random_seed=42               # For reproducibility
)

print(f"\n✅ POPULATION FROM BASE DATA CREATED:")

# Show diversity analysis
base_flat = opt_data['initial_solution']
distances = [np.linalg.norm(population_from_data[i] - base_flat) 
             for i in range(pop_size)]

print(f"\n📊 Population Diversity Analysis:")
print(f"   Mean distance from base: {np.mean(distances):.2f}")
print(f"   Std distance: {np.std(distances):.2f}")
print(f"   Min distance: {np.min(distances):.2f} (base solution)")
print(f"   Max distance: {np.max(distances):.2f}")

print("\n" + "-"*70)
print("STRATEGY B: SEEDING FROM SOLUTION LIST")
print("-"*70)

print("\n📋 The 'solution list' strategy:")
print("   • Uses multiple solutions as bases")
print("   • Creates perturbations around EACH base solution")

print(f"\n🔄 Loading and validating {len(flat_solutions_from_files)} previous solutions...")

# Use SolutionLoader to validate and convert flat solutions
# This handles the flat -> domain format conversion automatically
validated_solutions = solution_loader.load_solutions(
    flat_solutions_from_files,
    opt_data  # Reference opt_data for validation
)

print(f"✅ Solutions validated and converted to domain format:")
for i, sol in enumerate(validated_solutions, 1):
    if isinstance(sol, dict):
        print(f"   Solution {i}: PT shape {sol['pt'].shape}, DRT shape {sol['drt'].shape}")
    else:
        print(f"   Solution {i}: Shape {sol.shape}")

# Build population from solution list
population_from_list = population_builder.build_initial_population(
    problem=problem,
    pop_size=pop_size,
    optimization_data=opt_data,
    base_solutions=validated_solutions,  # Use loaded solutions
    frac_gaussian_pert=0.6,              # 60% perturbations, 40% LHS
    gaussian_sigma=0.3,                  # Smaller sigma (stay closer to good solutions)
    random_seed=123
)

print(f"\n✅ POPULATION FROM SOLUTION LIST CREATED:")

# Diversity analysis
diversity_metrics = []
for i, base_sol in enumerate(validated_solutions):
    base_encoded = problem.encode_solution(base_sol)
    distances_to_base = [np.linalg.norm(population_from_list[j] - base_encoded) 
                        for j in range(pop_size)]
    diversity_metrics.append(np.mean(distances_to_base))

print(f"\n📊 Multi-Solution Diversity:")
print(f"   Average distance to each base solution:")
for i, dist in enumerate(diversity_metrics, 1):
    print(f"      Base {i}: {dist:.2f}")
# Out:
# 📚 UNDERSTANDING THE SEEDING WORKFLOW:
#    1. Load base solutions (from GTFS or previous runs)
#    2. Use SolutionLoader to validate and format solutions
#    3. Use PopulationBuilder to create PSO initial population
#    4. Pass population to PSO via configuration
#
# 🔧 Creating optimization problem...
# 🗺️ Setting up spatial analysis with 2.0km resolution
# 🗺️  Reprojected 6897 stops to EPSG:3857
# 🎯 Applying boundary filter to 6897 stops...
# 🔍 Filtered 6897 → 4405 points
# ✅ Filtered to 4405 stops within boundary
# 🔧 Creating 27 × 26 = 702 grid cells
#    Grid bounds: (-195346, 7111759) to (-142657, 7161976) meters
#    Cell size: 2000.0m × 2000.0m
# ✅ Created 702 hexagonal zones in EPSG:3857
# 🎯 Applying boundary filter to 702 grid cells...
# 🔍 Filtered 702 → 552 grid cells
# ✅ Filtered to 552 grid cells within boundary
# 🚀 Using spatial join for zone mapping...
# ✅ Mapped 4405 stops to zones
# 🗺️ Computing DRT spatial intersections for 2 zones...
#    Hexagonal grid size: 552 zones
#    Zone drt_ne: affects 149 hexagonal zones
#    Zone drt_nw: affects 54 hexagonal zones
# 🚀 Pre-computing route-stop mappings...
# ✅ Cached stops for 187 routes
# ✅ Spatial system ready: 552 hexagonal zones
# 🏗️  CREATING TRANSIT OPTIMIZATION PROBLEM:
#    📊 Problem dimensions (PT+DRT):
#       PT Routes: 147
#       DRT Zones: 2
#       Time intervals: 4
#       PT Headway choices: 7
#    🔧 Pymoo parameters:
#       Decision variables: 596
#       Objectives: 1
#       Constraints: 0
#       Total variables: 596
#       PT variables: 588
#       DRT variables: 8
#    🚦 Hard constraints: 0 constraint(s)
#    📋 No constraints specified (unconstrained optimization)
#    ✅ Problem setup complete!
# ✅ Problem created:
#    Variables: 596
#    DRT enabled: True
#
# ----------------------------------------------------------------------
# STRATEGY A: SEEDING FROM BASE GTFS DATA ('from_data')
# ----------------------------------------------------------------------
#
# 📋 The 'from_data' strategy:
#    • Uses opt_data['initial_solution'] as the base
#    • Creates variations using Gaussian perturbations
#    • Fills remaining slots with Latin Hypercube Sampling (LHS)
#
# 🎯 KEY PARAMETER: frac_gaussian_pert
#    Controls the mix of perturbations vs random exploration:
#    • frac_gaussian_pert = 0.7 → 70% Gaussian + 30% LHS
#    • Higher value = more exploration near base solution
#    • Lower value = more random exploration
# 🔧 Building initial population (size=30):
#    🎲 Random seed set to: 42
#    📋 Base solution 1: shape (596,)
#    ✅ Loaded 1 base solutions
#    📊 Population distribution:
#       Base solutions: 1
#       Gaussian perturbations: 21
#       LHS samples: 8
#    ✅ Final population shape: (30, 596)
#    🎯 Ready for PSO algorithm
#
# ✅ POPULATION FROM BASE DATA CREATED:
#
# 📊 Population Diversity Analysis:
#    Mean distance from base: 32.12
#    Std distance: 25.19
#    Min distance: 0.00 (base solution)
#    Max distance: 76.06
#
# ----------------------------------------------------------------------
# STRATEGY B: SEEDING FROM SOLUTION LIST
# ----------------------------------------------------------------------
#
# 📋 The 'solution list' strategy:
#    • Uses multiple solutions as bases
#    • Creates perturbations around EACH base solution
#
# 🔄 Loading and validating 3 previous solutions...
# ✅ Solutions validated and converted to domain format:
#    Solution 1: PT shape (147, 4), DRT shape (2, 4)
#    Solution 2: PT shape (147, 4), DRT shape (2, 4)
#    Solution 3: PT shape (147, 4), DRT shape (2, 4)
# 🔧 Building initial population (size=30):
#    🎲 Random seed set to: 123
#    📋 Base solution 1: shape (596,)
#    📋 Base solution 2: shape (596,)
#    📋 Base solution 3: shape (596,)
#    ✅ Loaded 3 base solutions
#    📊 Population distribution:
#       Base solutions: 3
#       Gaussian perturbations: 18
#       LHS samples: 9
#    ✅ Final population shape: (30, 596)
#    🎯 Ready for PSO algorithm
#
# ✅ POPULATION FROM SOLUTION LIST CREATED:
#
# 📊 Multi-Solution Diversity:
#    Average distance to each base solution:
#       Base 1: 20.73
#       Base 2: 21.48
#       Base 3: 20.84

# %% [markdown]
# ## Running PSO with initial solutions
#
# Here we bring everything together. Above we were showing how the populations are built for demonstration purposes. When running a PSO algorithm, all of that is handled under the hood. All you need to specify is the sampling config:
#
#
# ``` python
# 'sampling': {
#     'enabled': True,
#     'base_solutions': 'from_data',  # Use base GTFS solution. Other option is List
#     'frac_gaussian_pert': 0.2, # 20%/80% for Gaussian pertubation/LHS()
#     'gaussian_sigma': 1.5,
#     'random_seed': 42
# }
# ```

# %% [markdown]
# ### Option 1: Running PSO with one initial solution
#
# Here we show an example of running PSO with one base sample (the initial GTFS solution). under the hodd, `PopulationBuilder` fills in the rest of the population using Gaussian perturbations and Latin Hypercube Sampling (LHS) so that it is the size of `pop_size`.

# %%
from transit_opt.optimisation.config.config_manager import OptimizationConfigManager
from transit_opt.optimisation.runners.pso_runner import PSORunner

print("\n📝 INTEGRATING SEEDING WITH PSO CONFIGURATION:")
print("   The seeding configuration goes in optimization.sampling section")

# Configuration WITH seeding from base data
config_with_seeding_from_data = {
    'problem': {
        'objective': {
            'type': 'HexagonalCoverageObjective',
            'spatial_resolution_km': 2.0,
            'boundary': study_boundary,
            'crs': 'EPSG:3857',
            'time_aggregation': 'average'
        },
        'constraints': [
            {
                'type': 'FleetTotalConstraintHandler',
                'baseline': 'current_peak',
                'tolerance': 0.30,
                'measure': 'peak'
            }
        ]
    },
    'optimization': {
        'algorithm': {
            'type': 'PSO',
            'pop_size': 60,
            'inertia_weight': 0.9,
            'cognitive_coeff': 2.0,
            'social_coeff': 2.0,
            'adaptive': True
        },
        'sampling': {
            'enabled': True,
            'base_solutions': 'from_data',  # Use base GTFS solution
            'frac_gaussian_pert': 0.2,
            'gaussian_sigma': 1.5,
            'random_seed': 42
        },
        'termination': {
            'max_generations': 30
        },
        'monitoring': {
            'progress_frequency': 5,
            'save_history': True
        }
    }
}

print("\n🚀 RUNNING PSO WITH 'FROM_DATA' SEEDING:")
print(f"   Population size: {config_with_seeding_from_data['optimization']['algorithm']['pop_size']}")
print(f"   Seeding: {config_with_seeding_from_data['optimization']['sampling']['frac_gaussian_pert']*100:.0f}% Gaussian perturbations")
print(f"   Generations: {config_with_seeding_from_data['optimization']['termination']['max_generations']}")

config_manager = OptimizationConfigManager(config_dict=config_with_seeding_from_data)
runner = PSORunner(config_manager)

result_from_data = runner.optimize(opt_data, track_best_n=3)

print(f"\n✅ OPTIMIZATION WITH 'FROM_DATA' SEEDING COMPLETE:")
print(f"   Best objective: {result_from_data.best_objective:.6f}")
print(f"   Runtime: {result_from_data.optimization_time:.1f}s")
print(f"   Generations: {result_from_data.generations_completed}")
print(f"   Feasible: {result_from_data.constraint_violations['feasible']}")
print(f"   Best solutions found: {len(result_from_data.best_feasible_solutions)}")

# Baseline comparison (no seeding)
print("\n📊 BASELINE: PSO WITHOUT SEEDING (for comparison)")

config_no_seeding = config_with_seeding_from_data.copy()
config_no_seeding['optimization']['sampling'] = {'enabled': False}

config_manager_baseline = OptimizationConfigManager(config_dict=config_no_seeding)
runner_baseline = PSORunner(config_manager_baseline)

result_baseline = runner_baseline.optimize(opt_data, track_best_n=3)

print(f"\n✅ BASELINE OPTIMIZATION COMPLETE:")
print(f"   Best objective: {result_baseline.best_objective:.6f}")
print(f"   Runtime: {result_baseline.optimization_time:.1f}s")

# Comparison
improvement = ((result_baseline.best_objective - result_from_data.best_objective) / 
               result_baseline.best_objective * 100)
print(f"\n📈 COMPARISON:")
print(f"   Improvement with seeding: {improvement:+.2f}%")
print(f"   Time difference: {result_from_data.optimization_time - result_baseline.optimization_time:+.1f}s")
# Out:
# 📝 INTEGRATING SEEDING WITH PSO CONFIGURATION:
#    The seeding configuration goes in optimization.sampling section
#
# 🚀 RUNNING PSO WITH 'FROM_DATA' SEEDING:
#    Population size: 60
#    Seeding: 20% Gaussian perturbations
#    Generations: 30
# 📋 Using provided configuration dictionary
# 🚀 STARTING PSO OPTIMIZATION
# 🗺️ Setting up spatial analysis with 2.0km resolution
# 🗺️  Reprojected 6897 stops to EPSG:3857
# 🎯 Applying boundary filter to 6897 stops...
# 🔍 Filtered 6897 → 4405 points
# ✅ Filtered to 4405 stops within boundary
# 🔧 Creating 27 × 26 = 702 grid cells
#    Grid bounds: (-195346, 7111759) to (-142657, 7161976) meters
#    Cell size: 2000.0m × 2000.0m
# ✅ Created 702 hexagonal zones in EPSG:3857
# 🎯 Applying boundary filter to 702 grid cells...
# 🔍 Filtered 702 → 552 grid cells
# ✅ Filtered to 552 grid cells within boundary
# 🚀 Using spatial join for zone mapping...
# ✅ Mapped 4405 stops to zones
# 🗺️ Computing DRT spatial intersections for 2 zones...
#    Hexagonal grid size: 552 zones
#    Zone drt_ne: affects 149 hexagonal zones
#    Zone drt_nw: affects 54 hexagonal zones
# 🚀 Pre-computing route-stop mappings...
# ✅ Cached stops for 187 routes
# ✅ Spatial system ready: 552 hexagonal zones
#    📋 Creating 1 constraint handler(s)...
#       Creating constraint 1: FleetTotalConstraintHandler
#          ✓ FleetTotal: 1 constraint(s)
# 🏗️  CREATING TRANSIT OPTIMIZATION PROBLEM:
#    📊 Problem dimensions (PT+DRT):
#       PT Routes: 147
#       DRT Zones: 2
#       Time intervals: 4
#       PT Headway choices: 7
#    🔧 Pymoo parameters:
#       Decision variables: 596
#       Objectives: 1
#       Constraints: 1
#       Total variables: 596
#       PT variables: 588
#       DRT variables: 8
#    🚦 Hard constraints: 1 constraint(s)
#    📋 Constraint breakdown:
#       1. FleetTotalConstraintHandler: 1 constraint(s)
#    ✅ Problem setup complete!
# ✅ Problem created successfully:
#    📊 Variables: 596
#    🚦 Total constraints: 1 (from 1 handler(s))
#    🎯 Objective: HexagonalCoverageObjective
#    📋 Constraint types: ['FleetTotalConstraintHandler']
#    🎯 Method: Hard constraints
# 🔧 Creating custom initial population...
# 🔧 Building initial population (size=60):
#    🎲 Random seed set to: 42
#    📋 Base solution 1: shape (596,)
#    ✅ Loaded 1 base solutions
#    📊 Population distribution:
#       Base solutions: 1
#       Gaussian perturbations: 12
#       LHS samples: 47
#    ✅ Final population shape: (60, 596)
#    🎯 Ready for PSO algorithm
# ✅ Custom population set: shape (60, 596)
#    📊 Gaussian fraction: 20.0%
#    📊 LHS fraction: 80.0% (calculated)
#
# 📋 OPTIMIZATION CONFIGURATION:
#    Algorithm: PSO (adaptive)
#    Population size: 60
#    Initial parameters: w=0.9, c1=2.0, c2=2.0
#    Adaptation: PyMOO adjusts parameters based on swarm diversity
#    Max generations: 30
#    Problem size: 596 variables, 1 constraints
#
# 📊 Running optimization (pymoo will show progress)...
# 📊 Calculating PT+DRT vehicles per zone... (eval #1)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 18289.0
# 📊 Vehicles per zone (average): min=0.0, max=650.75, var=3325.22
# 📊 Vehicles per zone (average): min=0.0, max=591.0, var=2885.27
# 📊 Vehicles per zone (average): min=0.0, max=570.5, var=2616.68
# 📊 Vehicles per zone (average): min=0.0, max=554.75, var=2436.53
# 📊 Vehicles per zone (average): min=0.0, max=583.25, var=2638.60
# 📊 Vehicles per zone (average): min=0.0, max=566.75, var=2511.14
# 📊 Vehicles per zone (average): min=0.0, max=557.75, var=2423.18
# 📊 Vehicles per zone (average): min=0.0, max=593.25, var=2772.19
# 📊 Vehicles per zone (average): min=0.0, max=585.5, var=2640.92
# 📊 Vehicles per zone (average): min=0.0, max=585.5, var=2730.70
# 📊 Vehicles per zone (average): min=0.0, max=593.0, var=2884.27
# 📊 Vehicles per zone (average): min=0.0, max=568.25, var=2547.01
# 📊 Vehicles per zone (average): min=0.0, max=576.75, var=2676.36
# 📊 Vehicles per zone (average): min=0.0, max=329.0, var=1163.10
# 📊 Vehicles per zone (average): min=0.0, max=305.75, var=1322.14
# 📊 Vehicles per zone (average): min=0.0, max=333.5, var=1645.39
# 📊 Vehicles per zone (average): min=0.0, max=351.0, var=1058.66
# 📊 Vehicles per zone (average): min=0.0, max=346.0, var=1253.34
# 📊 Vehicles per zone (average): min=0.0, max=349.75, var=1273.31
# 📊 Vehicles per zone (average): min=0.0, max=325.25, var=1088.97
# 📊 Vehicles per zone (average): min=0.0, max=339.5, var=1106.44
# 📊 Vehicles per zone (average): min=0.0, max=382.25, var=1337.24
# 📊 Vehicles per zone (average): min=0.0, max=354.5, var=1780.05
# 📊 Vehicles per zone (average): min=0.0, max=350.25, var=1223.88
# 📊 Vehicles per zone (average): min=0.0, max=348.0, var=1264.29
# 📊 Vehicles per zone (average): min=0.0, max=344.75, var=1463.13
# 📊 Vehicles per zone (average): min=0.0, max=335.75, var=2508.97
# 📊 Vehicles per zone (average): min=0.0, max=351.75, var=1301.79
# 📊 Vehicles per zone (average): min=0.0, max=346.5, var=1457.14
# 📊 Vehicles per zone (average): min=0.0, max=333.5, var=1059.68
# 📊 Vehicles per zone (average): min=0.0, max=380.75, var=1961.77
# 📊 Vehicles per zone (average): min=0.0, max=310.75, var=1341.52
# 📊 Vehicles per zone (average): min=0.0, max=341.0, var=1080.29
# 📊 Vehicles per zone (average): min=0.0, max=354.5, var=1104.55
# 📊 Vehicles per zone (average): min=0.0, max=355.75, var=1217.34
# 📊 Vehicles per zone (average): min=0.0, max=339.5, var=1353.52
# 📊 Vehicles per zone (average): min=0.0, max=339.75, var=1588.88
# 📊 Vehicles per zone (average): min=0.0, max=359.5, var=1388.33
# 📊 Vehicles per zone (average): min=0.0, max=323.5, var=1624.92
# 📊 Vehicles per zone (average): min=0.0, max=387.5, var=2283.10
# 📊 Vehicles per zone (average): min=0.0, max=344.75, var=1245.05
# 📊 Vehicles per zone (average): min=0.0, max=330.0, var=1272.38
# 📊 Vehicles per zone (average): min=0.0, max=329.75, var=1000.28
# 📊 Vehicles per zone (average): min=0.0, max=344.5, var=1124.93
# 📊 Vehicles per zone (average): min=0.0, max=349.25, var=1232.76
# 📊 Vehicles per zone (average): min=0.0, max=309.0, var=984.56
# 📊 Vehicles per zone (average): min=0.0, max=356.5, var=1353.84
# 📊 Vehicles per zone (average): min=0.0, max=343.0, var=1269.49
# 📊 Vehicles per zone (average): min=0.0, max=372.0, var=1842.49
# 📊 Calculating PT+DRT vehicles per zone... (eval #50)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 20224.0
# 📊 Vehicles per zone (average): min=0.0, max=334.75, var=1139.37
# 📊 Vehicles per zone (average): min=0.0, max=355.25, var=1520.56
# 📊 Vehicles per zone (average): min=0.0, max=320.25, var=1052.65
# 📊 Vehicles per zone (average): min=0.0, max=312.25, var=1087.10
# 📊 Vehicles per zone (average): min=0.0, max=348.25, var=1085.51
# 📊 Vehicles per zone (average): min=0.0, max=351.75, var=1456.87
# 📊 Vehicles per zone (average): min=0.0, max=358.75, var=1086.42
# 📊 Vehicles per zone (average): min=0.0, max=331.5, var=1066.47
# 📊 Vehicles per zone (average): min=0.0, max=347.75, var=1273.72
# 📊 Vehicles per zone (average): min=0.0, max=333.75, var=2296.26
# 📊 Vehicles per zone (average): min=0.0, max=346.5, var=1181.47
#    📊 Evaluation summary:
#       Best objective: 984.5566
#       Worst objective: 3325.2155
#       Average objective: 1648.5340
#       Feasible solutions: 60/60
# ======================================================================================================================================
# n_gen  |  n_eval  |    f     |    S    |    w    |    c1    |    c2    |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ======================================================================================================================================
#      1 |       60 |        - |       - |  0.9000 |  2.00000 |  2.00000 |  0.000000E+00 |  0.000000E+00 |  1.648534E+03 |  9.845566E+02
# 📊 Vehicles per zone (average): min=0.0, max=473.0, var=1834.05
# 📊 Vehicles per zone (average): min=0.0, max=429.0, var=1550.85
# 📊 Vehicles per zone (average): min=0.0, max=413.0, var=1425.55
# 📊 Vehicles per zone (average): min=0.0, max=397.5, var=1284.08
# 📊 Vehicles per zone (average): min=0.0, max=414.0, var=1400.61
# 📊 Vehicles per zone (average): min=0.0, max=417.5, var=1399.26
# 📊 Vehicles per zone (average): min=0.0, max=406.75, var=1327.77
# 📊 Vehicles per zone (average): min=0.0, max=423.0, var=1475.55
# 📊 Vehicles per zone (average): min=0.0, max=427.75, var=1493.92
# 📊 Vehicles per zone (average): min=0.0, max=423.0, var=1498.43
# 📊 Vehicles per zone (average): min=0.0, max=426.5, var=1599.21
# 📊 Vehicles per zone (average): min=0.0, max=407.0, var=1364.69
# 📊 Vehicles per zone (average): min=0.0, max=421.0, var=1498.04
# 📊 Vehicles per zone (average): min=0.0, max=258.25, var=680.33
# 📊 Vehicles per zone (average): min=0.0, max=245.5, var=852.04
# 📊 Vehicles per zone (average): min=0.0, max=257.5, var=1133.12
# 📊 Vehicles per zone (average): min=0.0, max=278.0, var=702.75
# 📊 Vehicles per zone (average): min=0.0, max=274.0, var=1128.21
# 📊 Vehicles per zone (average): min=0.0, max=274.25, var=861.26
# 📊 Vehicles per zone (average): min=0.0, max=257.25, var=770.61
# 📊 Vehicles per zone (average): min=0.0, max=265.75, var=775.34
# 📊 Vehicles per zone (average): min=0.0, max=298.5, var=908.49
# 📊 Vehicles per zone (average): min=0.0, max=271.75, var=853.95
# 📊 Vehicles per zone (average): min=0.0, max=274.25, var=868.01
# 📊 Vehicles per zone (average): min=0.0, max=277.25, var=785.25
# 📊 Vehicles per zone (average): min=0.0, max=259.5, var=721.45
# 📊 Vehicles per zone (average): min=0.0, max=270.5, var=1350.33
# 📊 Vehicles per zone (average): min=0.0, max=267.75, var=687.60
# 📊 Vehicles per zone (average): min=0.0, max=274.0, var=999.83
# 📊 Vehicles per zone (average): min=0.0, max=266.0, var=747.31
# 📊 Vehicles per zone (average): min=0.0, max=294.0, var=1016.04
# 📊 Vehicles per zone (average): min=0.0, max=251.75, var=771.89
# 📊 Vehicles per zone (average): min=0.0, max=275.0, var=812.61
# 📊 Vehicles per zone (average): min=0.0, max=270.0, var=732.04
# 📊 Vehicles per zone (average): min=0.0, max=271.5, var=790.38
# 📊 Vehicles per zone (average): min=0.0, max=278.0, var=922.93
# 📊 Vehicles per zone (average): min=0.0, max=261.25, var=840.33
# 📊 Vehicles per zone (average): min=0.0, max=279.0, var=965.13
# 📊 Vehicles per zone (average): min=0.0, max=266.75, var=829.62
# 📊 Calculating PT+DRT vehicles per zone... (eval #100)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 15954.0
# 📊 Vehicles per zone (average): min=0.0, max=299.25, var=1114.75
# 📊 Vehicles per zone (average): min=0.0, max=265.75, var=1007.14
# 📊 Vehicles per zone (average): min=0.0, max=258.25, var=760.83
# 📊 Vehicles per zone (average): min=0.0, max=270.0, var=707.56
# 📊 Vehicles per zone (average): min=0.0, max=276.5, var=756.60
# 📊 Vehicles per zone (average): min=0.0, max=272.0, var=993.42
# 📊 Vehicles per zone (average): min=0.0, max=309.0, var=983.62
# 📊 Vehicles per zone (average): min=0.0, max=273.5, var=803.93
# 📊 Vehicles per zone (average): min=0.0, max=275.5, var=861.33
# 📊 Vehicles per zone (average): min=0.0, max=283.25, var=845.30
# 📊 Vehicles per zone (average): min=0.0, max=267.25, var=820.56
# 📊 Vehicles per zone (average): min=0.0, max=270.25, var=935.33
# 📊 Vehicles per zone (average): min=0.0, max=256.75, var=750.44
# 📊 Vehicles per zone (average): min=0.0, max=245.5, var=659.90
# 📊 Vehicles per zone (average): min=0.0, max=278.75, var=737.60
# 📊 Vehicles per zone (average): min=0.0, max=284.75, var=852.43
# 📊 Vehicles per zone (average): min=0.0, max=271.5, var=688.82
# 📊 Vehicles per zone (average): min=0.0, max=280.75, var=761.01
# 📊 Vehicles per zone (average): min=0.0, max=266.5, var=862.03
# 📊 Vehicles per zone (average): min=0.0, max=264.0, var=1222.10
# 📊 Vehicles per zone (average): min=0.0, max=272.5, var=786.92
#    📊 Evaluation summary:
#       Best objective: 659.9011
#       Worst objective: 1834.0514
#       Average objective: 992.8412
#       Feasible solutions: 60/60
#      2 |      120 | -4.7E-03 |       3 |  0.3970 |  2.00000 |  2.01313 |  0.000000E+00 |  0.000000E+00 |  9.928412E+02 |  6.599011E+02
# 📊 Vehicles per zone (average): min=0.0, max=308.75, var=880.93
# 📊 Vehicles per zone (average): min=0.0, max=291.75, var=807.10
# 📊 Vehicles per zone (average): min=0.0, max=294.0, var=799.98
# 📊 Vehicles per zone (average): min=0.0, max=281.75, var=767.74
# 📊 Vehicles per zone (average): min=0.0, max=292.5, var=796.57
# 📊 Vehicles per zone (average): min=0.0, max=296.75, var=778.04
# 📊 Vehicles per zone (average): min=0.0, max=287.25, var=734.15
# 📊 Vehicles per zone (average): min=0.0, max=295.0, var=816.39
# 📊 Vehicles per zone (average): min=0.0, max=302.0, var=776.62
# 📊 Vehicles per zone (average): min=0.0, max=298.0, var=871.99
# 📊 Vehicles per zone (average): min=0.0, max=303.5, var=928.01
# 📊 Vehicles per zone (average): min=0.0, max=289.75, var=823.82
# 📊 Vehicles per zone (average): min=0.0, max=290.25, var=810.93
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=604.33
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=668.19
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=748.57
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=554.31
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=701.44
# 📊 Vehicles per zone (average): min=0.0, max=242.75, var=605.20
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=699.14
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=617.36
# 📊 Vehicles per zone (average): min=0.0, max=249.25, var=653.83
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=616.87
# 📊 Vehicles per zone (average): min=0.0, max=242.5, var=697.66
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=726.30
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=642.57
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=726.36
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=610.58
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=645.03
# 📊 Calculating PT+DRT vehicles per zone... (eval #150)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 14596.0
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=609.54
# 📊 Vehicles per zone (average): min=0.0, max=242.0, var=728.29
# 📊 Vehicles per zone (average): min=0.0, max=228.25, var=613.93
# 📊 Vehicles per zone (average): min=0.0, max=240.5, var=670.47
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=606.67
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=567.40
# 📊 Vehicles per zone (average): min=0.0, max=239.5, var=634.46
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=570.62
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=677.03
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=665.80
# 📊 Vehicles per zone (average): min=0.0, max=253.25, var=833.13
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=727.18
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=625.22
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=599.11
# 📊 Vehicles per zone (average): min=0.0, max=241.0, var=635.78
# 📊 Vehicles per zone (average): min=0.0, max=236.75, var=694.38
# 📊 Vehicles per zone (average): min=0.0, max=249.75, var=806.58
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=631.08
# 📊 Vehicles per zone (average): min=0.0, max=243.5, var=643.82
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=674.08
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=692.98
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=671.98
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=649.44
# 📊 Vehicles per zone (average): min=0.0, max=245.5, var=659.90
# 📊 Vehicles per zone (average): min=0.0, max=244.5, var=668.40
# 📊 Vehicles per zone (average): min=0.0, max=241.25, var=645.08
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=611.40
# 📊 Vehicles per zone (average): min=0.0, max=245.5, var=586.85
# 📊 Vehicles per zone (average): min=0.0, max=228.25, var=603.49
# 📊 Vehicles per zone (average): min=0.0, max=232.25, var=798.97
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=572.41
#    📊 Evaluation summary:
#       Best objective: 554.3134
#       Worst objective: 928.0093
#       Average objective: 691.4246
#       Feasible solutions: 60/60
#      3 |      180 |  0.01587 |       3 |  0.4099 |  1.99360 |  2.03120 |  0.000000E+00 |  0.000000E+00 |  6.914246E+02 |  5.543134E+02
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=568.11
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=623.60
# 📊 Vehicles per zone (average): min=0.0, max=245.0, var=616.30
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=592.71
# 📊 Vehicles per zone (average): min=0.0, max=234.0, var=583.97
# 📊 Vehicles per zone (average): min=0.0, max=246.25, var=585.59
# 📊 Vehicles per zone (average): min=0.0, max=240.0, var=593.30
# 📊 Vehicles per zone (average): min=0.0, max=246.5, var=698.07
# 📊 Vehicles per zone (average): min=0.0, max=243.0, var=597.46
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=554.64
# 📊 Vehicles per zone (average): min=0.0, max=241.75, var=673.18
# 📊 Vehicles per zone (average): min=0.0, max=239.0, var=620.73
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=532.03
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=594.45
# 📊 Vehicles per zone (average): min=0.0, max=239.0, var=721.47
# 📊 Vehicles per zone (average): min=0.0, max=224.75, var=557.96
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=554.31
# 📊 Vehicles per zone (average): min=0.0, max=236.75, var=670.78
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=546.87
# 📊 Calculating PT+DRT vehicles per zone... (eval #200)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 12871.0
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=621.06
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=631.49
# 📊 Vehicles per zone (average): min=0.0, max=242.75, var=673.86
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=569.44
# 📊 Vehicles per zone (average): min=0.0, max=241.5, var=702.72
# 📊 Vehicles per zone (average): min=0.0, max=240.0, var=608.10
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=574.12
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=619.68
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=628.26
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=606.96
# 📊 Vehicles per zone (average): min=0.0, max=223.75, var=566.26
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=576.17
# 📊 Vehicles per zone (average): min=0.0, max=240.5, var=618.29
# 📊 Vehicles per zone (average): min=0.0, max=242.75, var=686.04
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=593.52
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=549.24
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=656.85
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=555.35
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=736.54
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=570.25
# 📊 Vehicles per zone (average): min=0.0, max=241.25, var=638.91
# 📊 Vehicles per zone (average): min=0.0, max=240.0, var=731.44
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=577.14
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=542.83
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=706.01
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=589.62
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=694.32
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=539.69
# 📊 Vehicles per zone (average): min=0.0, max=238.0, var=679.54
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=636.02
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=587.36
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=631.62
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=662.72
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=585.56
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=607.33
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=623.73
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=587.06
# 📊 Vehicles per zone (average): min=0.0, max=244.0, var=672.26
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=630.64
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=559.21
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=549.75
#    📊 Evaluation summary:
#       Best objective: 532.0311
#       Worst objective: 736.5439
#       Average objective: 614.3748
#       Feasible solutions: 60/60
#      4 |      240 |  0.13705 |       3 |  0.4877 |  1.98171 |  2.04574 |  0.000000E+00 |  0.000000E+00 |  6.069072E+02 |  5.320311E+02
# 📊 Vehicles per zone (average): min=0.0, max=226.75, var=614.37
# 📊 Vehicles per zone (average): min=0.0, max=226.75, var=579.17
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=585.97
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=736.43
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=737.10
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=606.37
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=617.06
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=696.94
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=585.11
# 📊 Calculating PT+DRT vehicles per zone... (eval #250)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 15072.0
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=603.20
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=644.85
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=598.60
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=532.03
# 📊 Vehicles per zone (average): min=0.0, max=249.5, var=599.59
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=547.53
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=566.77
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=619.29
# 📊 Vehicles per zone (average): min=0.0, max=245.25, var=651.04
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=645.33
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=646.59
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=559.89
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=576.14
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=631.92
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=567.76
# 📊 Vehicles per zone (average): min=0.0, max=244.5, var=641.83
# 📊 Vehicles per zone (average): min=0.0, max=247.0, var=602.84
# 📊 Vehicles per zone (average): min=0.0, max=242.75, var=585.59
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=574.59
# 📊 Vehicles per zone (average): min=0.0, max=250.0, var=619.49
# 📊 Vehicles per zone (average): min=0.0, max=243.5, var=593.63
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=621.32
# 📊 Vehicles per zone (average): min=0.0, max=226.25, var=541.39
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=564.41
# 📊 Vehicles per zone (average): min=0.0, max=241.75, var=623.48
# 📊 Vehicles per zone (average): min=0.0, max=242.5, var=572.52
# 📊 Vehicles per zone (average): min=0.0, max=238.0, var=554.66
# 📊 Vehicles per zone (average): min=0.0, max=245.25, var=572.89
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=584.83
# 📊 Vehicles per zone (average): min=0.0, max=240.0, var=559.52
# 📊 Vehicles per zone (average): min=0.0, max=240.75, var=615.93
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=581.26
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=630.69
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=630.68
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=584.59
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=656.80
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=644.04
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=619.38
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=544.80
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=616.56
# 📊 Vehicles per zone (average): min=0.0, max=246.25, var=643.44
# 📊 Vehicles per zone (average): min=0.0, max=242.75, var=624.49
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=673.09
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=635.17
# 📊 Vehicles per zone (average): min=0.0, max=248.5, var=661.64
# 📊 Vehicles per zone (average): min=0.0, max=242.0, var=644.47
# 📊 Vehicles per zone (average): min=0.0, max=247.0, var=658.00
# 📊 Vehicles per zone (average): min=0.0, max=239.0, var=578.24
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=605.98
# 📊 Vehicles per zone (average): min=0.0, max=247.75, var=637.03
# 📊 Calculating PT+DRT vehicles per zone... (eval #300)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 15730.0
# 📊 Vehicles per zone (average): min=0.0, max=244.75, var=583.49
#    📊 Evaluation summary:
#       Best objective: 532.0311
#       Worst objective: 737.0967
#       Average objective: 610.5299
#       Feasible solutions: 60/60
#      5 |      300 | -3.0E-02 |       3 |  0.3815 |  1.96874 |  2.05524 |  0.000000E+00 |  0.000000E+00 |  5.839041E+02 |  5.320311E+02
# 📊 Vehicles per zone (average): min=0.0, max=245.0, var=561.91
# 📊 Vehicles per zone (average): min=0.0, max=241.5, var=576.79
# 📊 Vehicles per zone (average): min=0.0, max=243.0, var=571.53
# 📊 Vehicles per zone (average): min=0.0, max=245.25, var=636.23
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=576.25
# 📊 Vehicles per zone (average): min=0.0, max=243.75, var=564.24
# 📊 Vehicles per zone (average): min=0.0, max=252.75, var=600.19
# 📊 Vehicles per zone (average): min=0.0, max=242.5, var=562.90
# 📊 Vehicles per zone (average): min=0.0, max=241.75, var=639.18
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=546.02
# 📊 Vehicles per zone (average): min=0.0, max=236.75, var=544.78
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=622.11
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=532.03
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=578.78
# 📊 Vehicles per zone (average): min=0.0, max=245.5, var=611.00
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=529.20
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=535.60
# 📊 Vehicles per zone (average): min=0.0, max=243.5, var=577.10
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=543.69
# 📊 Vehicles per zone (average): min=0.0, max=247.0, var=735.02
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=606.58
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=564.91
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=531.70
# 📊 Vehicles per zone (average): min=0.0, max=245.75, var=585.25
# 📊 Vehicles per zone (average): min=0.0, max=241.5, var=590.51
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=632.36
# 📊 Vehicles per zone (average): min=0.0, max=249.25, var=658.77
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=586.70
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=529.27
# 📊 Vehicles per zone (average): min=0.0, max=229.75, var=587.81
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=560.08
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=559.87
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=561.66
# 📊 Vehicles per zone (average): min=0.0, max=239.0, var=634.25
# 📊 Vehicles per zone (average): min=0.0, max=236.5, var=567.21
# 📊 Vehicles per zone (average): min=0.0, max=245.75, var=615.58
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=574.74
# 📊 Vehicles per zone (average): min=0.0, max=244.25, var=576.20
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=543.98
# 📊 Vehicles per zone (average): min=0.0, max=239.5, var=628.42
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=629.65
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=551.35
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=593.89
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=538.07
# 📊 Vehicles per zone (average): min=0.0, max=241.0, var=620.85
# 📊 Vehicles per zone (average): min=0.0, max=244.25, var=572.74
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=558.41
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=555.81
# 📊 Vehicles per zone (average): min=0.0, max=241.5, var=625.81
# 📊 Calculating PT+DRT vehicles per zone... (eval #350)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 12542.0
# 📊 Vehicles per zone (average): min=0.0, max=240.5, var=589.81
# 📊 Vehicles per zone (average): min=0.0, max=248.0, var=643.10
# 📊 Vehicles per zone (average): min=0.0, max=243.0, var=628.71
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=578.74
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=649.32
# 📊 Vehicles per zone (average): min=0.0, max=224.25, var=534.04
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=602.03
# 📊 Vehicles per zone (average): min=0.0, max=241.0, var=586.49
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=606.27
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=568.08
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=555.50
#    📊 Evaluation summary:
#       Best objective: 529.1994
#       Worst objective: 735.0172
#       Average objective: 585.4846
#       Feasible solutions: 60/60
#      6 |      360 | -2.1E-02 |       3 |  0.3871 |  1.95804 |  2.07223 |  0.000000E+00 |  0.000000E+00 |  5.691849E+02 |  5.291994E+02
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=577.93
# 📊 Vehicles per zone (average): min=0.0, max=242.5, var=596.68
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=581.84
# 📊 Vehicles per zone (average): min=0.0, max=247.0, var=598.01
# 📊 Vehicles per zone (average): min=0.0, max=243.0, var=567.41
# 📊 Vehicles per zone (average): min=0.0, max=243.75, var=623.48
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=547.05
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=562.87
# 📊 Vehicles per zone (average): min=0.0, max=228.25, var=537.75
# 📊 Vehicles per zone (average): min=0.0, max=240.75, var=577.30
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=535.58
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=662.48
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=549.02
# 📊 Vehicles per zone (average): min=0.0, max=240.75, var=573.52
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=556.24
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=529.20
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=561.28
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=579.17
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=632.70
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=602.20
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=549.02
# 📊 Vehicles per zone (average): min=0.0, max=225.5, var=531.00
# 📊 Vehicles per zone (average): min=0.0, max=232.0, var=582.31
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=540.18
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=608.38
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=696.73
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=561.06
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=552.95
# 📊 Vehicles per zone (average): min=0.0, max=232.25, var=583.01
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=556.65
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=544.42
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=561.50
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=570.70
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=527.62
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=544.12
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=546.86
# 📊 Vehicles per zone (average): min=0.0, max=229.75, var=525.53
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=602.87
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=544.87
# 📊 Calculating PT+DRT vehicles per zone... (eval #400)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 12553.0
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=600.31
# 📊 Vehicles per zone (average): min=0.0, max=232.0, var=561.61
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=599.88
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=574.94
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=597.81
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=565.53
# 📊 Vehicles per zone (average): min=0.0, max=232.25, var=548.91
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=558.10
# 📊 Vehicles per zone (average): min=0.0, max=228.5, var=547.61
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=546.61
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=566.07
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=560.54
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=593.10
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=609.40
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=596.36
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=560.78
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=591.07
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=508.63
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=579.99
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=594.50
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=532.45
#    📊 Evaluation summary:
#       Best objective: 508.6277
#       Worst objective: 696.7298
#       Average objective: 571.2613
#       Feasible solutions: 60/60
#      7 |      420 | -3.5E-02 |       3 |  0.3784 |  1.94423 |  2.07914 |  0.000000E+00 |  0.000000E+00 |  5.561244E+02 |  5.086277E+02
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=522.17
# 📊 Vehicles per zone (average): min=0.0, max=236.75, var=545.82
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=555.29
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=582.82
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=567.06
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=576.65
# 📊 Vehicles per zone (average): min=0.0, max=224.0, var=518.77
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=607.60
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=556.14
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=521.21
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=504.87
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=575.16
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=526.86
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=594.57
# 📊 Vehicles per zone (average): min=0.0, max=225.0, var=545.38
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=519.44
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=634.95
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=540.61
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=578.31
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=537.75
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=548.36
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=553.99
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=532.15
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=591.85
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=550.63
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=519.87
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=596.69
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=532.79
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=521.32
# 📊 Calculating PT+DRT vehicles per zone... (eval #450)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 12655.0
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=552.90
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=551.06
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=545.74
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=544.96
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=550.72
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=647.44
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=528.42
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=537.38
# 📊 Vehicles per zone (average): min=0.0, max=243.0, var=537.30
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=533.01
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=587.67
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=580.82
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=566.92
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=550.45
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=512.58
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=571.43
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=597.49
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=550.38
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=502.82
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=545.56
# 📊 Vehicles per zone (average): min=0.0, max=236.5, var=550.67
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=548.84
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=555.75
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=576.08
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=564.04
# 📊 Vehicles per zone (average): min=0.0, max=228.5, var=510.56
# 📊 Vehicles per zone (average): min=0.0, max=236.75, var=567.32
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=508.63
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=583.54
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=518.13
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=552.97
#    📊 Evaluation summary:
#       Best objective: 502.8210
#       Worst objective: 647.4431
#       Average objective: 553.1776
#       Feasible solutions: 60/60
#      8 |      480 | -2.5E-02 |       3 |  0.3844 |  1.93411 |  2.08944 |  0.000000E+00 |  0.000000E+00 |  5.428073E+02 |  5.028210E+02
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=510.75
# 📊 Vehicles per zone (average): min=0.0, max=232.25, var=540.19
# 📊 Vehicles per zone (average): min=0.0, max=228.25, var=521.61
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=574.91
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=571.25
# 📊 Vehicles per zone (average): min=0.0, max=241.75, var=572.84
# 📊 Vehicles per zone (average): min=0.0, max=232.0, var=505.86
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=535.76
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=487.47
# 📊 Vehicles per zone (average): min=0.0, max=230.25, var=514.83
# 📊 Vehicles per zone (average): min=0.0, max=226.75, var=515.54
# 📊 Vehicles per zone (average): min=0.0, max=232.0, var=510.27
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=529.91
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=595.93
# 📊 Vehicles per zone (average): min=0.0, max=223.0, var=524.00
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=524.88
# 📊 Vehicles per zone (average): min=0.0, max=239.0, var=563.81
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=519.28
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=520.96
# 📊 Calculating PT+DRT vehicles per zone... (eval #500)
# 🔍 System peak analysis:
#    Peak interval: 3 (18-24h)
#    Peak total vehicles: 11723.0
# 📊 Vehicles per zone (average): min=0.0, max=243.75, var=575.71
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=503.28
# 📊 Vehicles per zone (average): min=0.0, max=224.75, var=497.87
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=556.26
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=535.91
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=515.45
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=532.23
# 📊 Vehicles per zone (average): min=0.0, max=223.5, var=498.86
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=505.12
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=489.88
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=493.93
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=527.53
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=567.32
# 📊 Vehicles per zone (average): min=0.0, max=241.75, var=573.42
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=477.46
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=508.75
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=539.73
# 📊 Vehicles per zone (average): min=0.0, max=224.0, var=529.91
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=548.10
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=543.34
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=506.00
# 📊 Vehicles per zone (average): min=0.0, max=224.0, var=493.24
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=516.86
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=523.06
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=580.05
# 📊 Vehicles per zone (average): min=0.0, max=225.0, var=540.94
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=492.13
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=503.38
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=502.82
# 📊 Vehicles per zone (average): min=0.0, max=225.5, var=528.62
# 📊 Vehicles per zone (average): min=0.0, max=227.5, var=509.80
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=503.76
# 📊 Vehicles per zone (average): min=0.0, max=225.75, var=500.90
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=482.64
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=583.41
# 📊 Vehicles per zone (average): min=0.0, max=224.0, var=521.53
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=534.03
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=517.15
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=550.84
# 📊 Vehicles per zone (average): min=0.0, max=223.75, var=537.45
# 📊 Vehicles per zone (average): min=0.0, max=232.0, var=554.87
#    📊 Evaluation summary:
#       Best objective: 477.4571
#       Worst objective: 595.9313
#       Average objective: 527.3927
#       Feasible solutions: 60/60
#      9 |      540 | -2.7E-02 |       3 |  0.3836 |  1.92386 |  2.09592 |  0.000000E+00 |  0.000000E+00 |  5.207804E+02 |  4.774571E+02
# 📊 Vehicles per zone (average): min=0.0, max=226.75, var=502.11
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=506.38
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=516.63
# 📊 Vehicles per zone (average): min=0.0, max=229.75, var=497.81
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=543.59
# 📊 Vehicles per zone (average): min=0.0, max=241.25, var=583.86
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=491.02
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=495.86
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=496.99
# 📊 Calculating PT+DRT vehicles per zone... (eval #550)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 11733.0
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=502.61
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=512.52
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=495.67
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=507.08
# 📊 Vehicles per zone (average): min=0.0, max=236.5, var=545.72
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=499.12
# 📊 Vehicles per zone (average): min=0.0, max=226.25, var=485.66
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=522.89
# 📊 Vehicles per zone (average): min=0.0, max=230.25, var=533.74
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=510.27
# 📊 Vehicles per zone (average): min=0.0, max=238.5, var=562.84
# 📊 Vehicles per zone (average): min=0.0, max=238.0, var=563.83
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=490.06
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=595.21
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=483.48
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=529.40
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=508.35
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=490.80
# 📊 Vehicles per zone (average): min=0.0, max=226.5, var=493.13
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=477.24
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=558.88
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=501.00
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=536.68
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=520.57
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=477.46
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=491.20
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=528.28
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=477.01
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=553.88
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=506.55
# 📊 Vehicles per zone (average): min=0.0, max=224.75, var=486.12
# 📊 Vehicles per zone (average): min=0.0, max=225.75, var=477.81
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=508.81
# 📊 Vehicles per zone (average): min=0.0, max=239.25, var=540.54
# 📊 Vehicles per zone (average): min=0.0, max=236.5, var=542.36
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=548.28
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=473.56
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=512.17
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=517.41
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=514.95
# 📊 Vehicles per zone (average): min=0.0, max=227.5, var=505.58
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=520.63
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=493.70
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=526.76
# 📊 Vehicles per zone (average): min=0.0, max=233.75, var=564.82
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=497.37
# 📊 Vehicles per zone (average): min=0.0, max=227.5, var=506.56
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=565.54
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=558.09
# 📊 Vehicles per zone (average): min=0.0, max=226.75, var=507.87
# 📊 Calculating PT+DRT vehicles per zone... (eval #600)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 13026.0
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=556.99
#    📊 Evaluation summary:
#       Best objective: 473.5577
#       Worst objective: 595.2058
#       Average objective: 517.0217
#       Feasible solutions: 60/60
#     10 |      600 | -2.3E-02 |       3 |  0.3859 |  1.91566 |  2.10411 |  0.000000E+00 |  0.000000E+00 |  5.082827E+02 |  4.735577E+02
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=514.74
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=504.73
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=520.72
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=498.36
# 📊 Vehicles per zone (average): min=0.0, max=242.0, var=539.02
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=596.05
# 📊 Vehicles per zone (average): min=0.0, max=242.5, var=541.54
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=499.72
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=527.69
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=503.09
# 📊 Vehicles per zone (average): min=0.0, max=240.5, var=575.42
# 📊 Vehicles per zone (average): min=0.0, max=239.0, var=545.41
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=509.87
# 📊 Vehicles per zone (average): min=0.0, max=231.75, var=493.73
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=547.99
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=488.33
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=510.66
# 📊 Vehicles per zone (average): min=0.0, max=225.75, var=472.51
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=512.60
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=505.54
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=489.53
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=511.55
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=509.83
# 📊 Vehicles per zone (average): min=0.0, max=237.25, var=511.62
# 📊 Vehicles per zone (average): min=0.0, max=226.5, var=501.82
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=543.37
# 📊 Vehicles per zone (average): min=0.0, max=241.25, var=549.02
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=493.16
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=496.02
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=499.39
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=503.95
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=540.32
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=487.50
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=495.44
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=510.35
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=511.78
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=524.25
# 📊 Vehicles per zone (average): min=0.0, max=239.5, var=522.54
# 📊 Vehicles per zone (average): min=0.0, max=228.25, var=478.82
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=510.14
# ...
# 📊 Vehicles per zone (average): min=0.0, max=225.5, var=461.50
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=448.02
# 📊 Vehicles per zone (average): min=0.0, max=221.25, var=434.38
# 📊 Vehicles per zone (average): min=0.0, max=221.0, var=423.83
# 📊 Vehicles per zone (average): min=0.0, max=222.0, var=424.51
# 📊 Vehicles per zone (average): min=0.0, max=221.75, var=424.62
# 📊 Vehicles per zone (average): min=0.0, max=214.5, var=404.19
# 📊 Vehicles per zone (average): min=0.0, max=219.25, var=417.85
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=457.98
# 📊 Vehicles per zone (average): min=0.0, max=229.75, var=462.22
# 📊 Vehicles per zone (average): min=0.0, max=215.25, var=409.43
# 📊 Vehicles per zone (average): min=0.0, max=228.0, var=453.80
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=428.72
# 📊 Vehicles per zone (average): min=0.0, max=217.0, var=407.72
# 📊 Vehicles per zone (average): min=0.0, max=219.75, var=431.00
# 📊 Vehicles per zone (average): min=0.0, max=227.75, var=443.87
# 📊 Vehicles per zone (average): min=0.0, max=220.5, var=428.59
# 📊 Vehicles per zone (average): min=0.0, max=224.0, var=429.24
# 📊 Vehicles per zone (average): min=0.0, max=225.5, var=433.83
# 📊 Calculating PT+DRT vehicles per zone... (eval #1600)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 9959.0
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=439.30
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=427.30
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=417.59
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=425.82
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=432.44
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=428.51
# 📊 Vehicles per zone (average): min=0.0, max=224.0, var=440.18
# 📊 Vehicles per zone (average): min=0.0, max=227.25, var=463.73
# 📊 Vehicles per zone (average): min=0.0, max=214.5, var=394.27
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=414.69
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=429.02
# 📊 Vehicles per zone (average): min=0.0, max=226.25, var=440.64
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=404.14
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=422.45
# 📊 Vehicles per zone (average): min=0.0, max=226.25, var=455.97
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=445.99
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=426.60
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=429.78
# 📊 Vehicles per zone (average): min=0.0, max=228.75, var=458.73
# 📊 Vehicles per zone (average): min=0.0, max=224.25, var=445.43
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=439.10
#    📊 Evaluation summary:
#       Best objective: 392.7384
#       Worst objective: 463.7251
#       Average objective: 431.7347
#       Feasible solutions: 60/60
#     27 |     1620 | -3.0E-02 |       3 |  0.3814 |  1.76463 |  2.25786 |  0.000000E+00 |  0.000000E+00 |  4.207843E+02 |  3.927384E+02
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=454.79
# 📊 Vehicles per zone (average): min=0.0, max=216.25, var=427.01
# 📊 Vehicles per zone (average): min=0.0, max=214.25, var=407.17
# 📊 Vehicles per zone (average): min=0.0, max=226.25, var=440.35
# 📊 Vehicles per zone (average): min=0.0, max=221.0, var=432.81
# 📊 Vehicles per zone (average): min=0.0, max=224.25, var=426.79
# 📊 Vehicles per zone (average): min=0.0, max=213.75, var=393.13
# 📊 Vehicles per zone (average): min=0.0, max=225.25, var=444.90
# 📊 Vehicles per zone (average): min=0.0, max=218.25, var=409.61
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=413.01
# 📊 Vehicles per zone (average): min=0.0, max=217.75, var=420.11
# 📊 Vehicles per zone (average): min=0.0, max=224.25, var=419.33
# 📊 Vehicles per zone (average): min=0.0, max=214.75, var=400.51
# 📊 Vehicles per zone (average): min=0.0, max=223.75, var=443.74
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=425.55
# 📊 Vehicles per zone (average): min=0.0, max=219.75, var=416.97
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=419.62
# 📊 Vehicles per zone (average): min=0.0, max=219.25, var=422.97
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=443.60
# 📊 Vehicles per zone (average): min=0.0, max=216.0, var=409.66
# 📊 Vehicles per zone (average): min=0.0, max=230.25, var=473.80
# 📊 Vehicles per zone (average): min=0.0, max=223.5, var=437.98
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=419.21
# 📊 Vehicles per zone (average): min=0.0, max=214.5, var=403.36
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=430.94
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=432.58
# 📊 Vehicles per zone (average): min=0.0, max=216.75, var=411.49
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=412.27
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=425.57
# 📊 Calculating PT+DRT vehicles per zone... (eval #1650)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 9977.0
# 📊 Vehicles per zone (average): min=0.0, max=215.5, var=404.42
# 📊 Vehicles per zone (average): min=0.0, max=216.5, var=413.05
# 📊 Vehicles per zone (average): min=0.0, max=216.75, var=405.88
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=406.80
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=423.06
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=403.77
# 📊 Vehicles per zone (average): min=0.0, max=219.25, var=424.24
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=450.27
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=401.85
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=432.43
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=417.68
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=431.09
# 📊 Vehicles per zone (average): min=0.0, max=221.0, var=424.81
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=420.79
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=427.79
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=421.15
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=413.63
# 📊 Vehicles per zone (average): min=0.0, max=219.25, var=412.80
# 📊 Vehicles per zone (average): min=0.0, max=216.25, var=399.20
# 📊 Vehicles per zone (average): min=0.0, max=216.5, var=411.97
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=436.30
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=432.72
# 📊 Vehicles per zone (average): min=0.0, max=215.0, var=402.48
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=422.80
# 📊 Vehicles per zone (average): min=0.0, max=224.75, var=443.77
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=412.13
# 📊 Vehicles per zone (average): min=0.0, max=216.75, var=411.04
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=442.42
# 📊 Vehicles per zone (average): min=0.0, max=221.0, var=426.80
# 📊 Vehicles per zone (average): min=0.0, max=219.75, var=442.40
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=411.78
#    📊 Evaluation summary:
#       Best objective: 393.1258
#       Worst objective: 473.7985
#       Average objective: 422.5028
#       Feasible solutions: 60/60
#     28 |     1680 | -3.3E-02 |       3 |  0.3797 |  1.76005 |  2.26689 |  0.000000E+00 |  0.000000E+00 |  4.160679E+02 |  3.927384E+02
# 📊 Vehicles per zone (average): min=0.0, max=220.5, var=442.08
# 📊 Vehicles per zone (average): min=0.0, max=215.5, var=406.55
# 📊 Vehicles per zone (average): min=0.0, max=214.25, var=417.60
# 📊 Vehicles per zone (average): min=0.0, max=219.25, var=426.86
# 📊 Vehicles per zone (average): min=0.0, max=218.75, var=423.31
# 📊 Vehicles per zone (average): min=0.0, max=217.75, var=426.96
# 📊 Vehicles per zone (average): min=0.0, max=213.75, var=392.74
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=454.25
# 📊 Vehicles per zone (average): min=0.0, max=224.25, var=424.16
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=423.76
# 📊 Vehicles per zone (average): min=0.0, max=219.75, var=426.39
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=412.91
# 📊 Vehicles per zone (average): min=0.0, max=219.25, var=415.72
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=412.75
# 📊 Vehicles per zone (average): min=0.0, max=213.75, var=394.44
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=387.90
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=423.34
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=410.89
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=425.84
# 📊 Calculating PT+DRT vehicles per zone... (eval #1700)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 10109.0
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=421.66
# 📊 Vehicles per zone (average): min=0.0, max=216.0, var=416.87
# 📊 Vehicles per zone (average): min=0.0, max=217.75, var=414.81
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=427.92
# 📊 Vehicles per zone (average): min=0.0, max=221.0, var=418.92
# 📊 Vehicles per zone (average): min=0.0, max=223.5, var=429.63
# 📊 Vehicles per zone (average): min=0.0, max=217.0, var=408.61
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=422.46
# 📊 Vehicles per zone (average): min=0.0, max=223.75, var=430.17
# 📊 Vehicles per zone (average): min=0.0, max=223.0, var=424.43
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=423.07
# 📊 Vehicles per zone (average): min=0.0, max=225.75, var=434.37
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=414.93
# 📊 Vehicles per zone (average): min=0.0, max=223.0, var=423.72
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=415.91
# 📊 Vehicles per zone (average): min=0.0, max=221.25, var=416.74
# 📊 Vehicles per zone (average): min=0.0, max=218.75, var=418.15
# 📊 Vehicles per zone (average): min=0.0, max=211.5, var=410.72
# 📊 Vehicles per zone (average): min=0.0, max=215.25, var=397.83
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=424.66
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=418.70
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=438.80
# 📊 Vehicles per zone (average): min=0.0, max=221.75, var=423.63
# 📊 Vehicles per zone (average): min=0.0, max=217.0, var=409.88
# 📊 Vehicles per zone (average): min=0.0, max=220.5, var=415.34
# 📊 Vehicles per zone (average): min=0.0, max=220.5, var=414.28
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=435.73
# 📊 Vehicles per zone (average): min=0.0, max=215.25, var=401.33
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=415.45
# 📊 Vehicles per zone (average): min=0.0, max=217.75, var=423.51
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=421.95
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=427.34
# 📊 Vehicles per zone (average): min=0.0, max=216.25, var=401.78
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=419.77
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=425.74
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=421.77
# 📊 Vehicles per zone (average): min=0.0, max=218.75, var=409.26
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=428.47
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=433.60
# 📊 Vehicles per zone (average): min=0.0, max=223.5, var=457.23
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=427.67
#    📊 Evaluation summary:
#       Best objective: 387.8956
#       Worst objective: 457.2270
#       Average objective: 420.2547
#       Feasible solutions: 60/60
#     29 |     1740 | -2.5E-02 |       3 |  0.3848 |  1.75268 |  2.27127 |  0.000000E+00 |  0.000000E+00 |  4.125390E+02 |  3.878956E+02
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=435.91
# 📊 Vehicles per zone (average): min=0.0, max=218.75, var=418.20
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=402.93
# 📊 Vehicles per zone (average): min=0.0, max=218.25, var=410.70
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=426.63
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=422.99
# 📊 Vehicles per zone (average): min=0.0, max=212.75, var=396.32
# 📊 Vehicles per zone (average): min=0.0, max=228.25, var=456.95
# 📊 Vehicles per zone (average): min=0.0, max=219.75, var=409.50
# 📊 Calculating PT+DRT vehicles per zone... (eval #1750)
# 🔍 System peak analysis:
#    Peak interval: 3 (18-24h)
#    Peak total vehicles: 10760.0
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=397.89
# 📊 Vehicles per zone (average): min=0.0, max=221.75, var=422.14
# 📊 Vehicles per zone (average): min=0.0, max=216.25, var=399.93
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=393.42
# 📊 Vehicles per zone (average): min=0.0, max=216.0, var=414.39
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=389.68
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=387.90
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=432.42
# 📊 Vehicles per zone (average): min=0.0, max=216.5, var=412.39
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=428.36
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=420.98
# 📊 Vehicles per zone (average): min=0.0, max=214.25, var=421.12
# 📊 Vehicles per zone (average): min=0.0, max=215.5, var=406.99
# 📊 Vehicles per zone (average): min=0.0, max=222.0, var=416.83
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=426.76
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=413.77
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=421.22
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=418.45
# 📊 Vehicles per zone (average): min=0.0, max=223.0, var=425.45
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=413.33
# 📊 Vehicles per zone (average): min=0.0, max=226.25, var=440.04
# 📊 Vehicles per zone (average): min=0.0, max=221.75, var=430.53
# 📊 Vehicles per zone (average): min=0.0, max=220.25, var=418.69
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=411.14
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=413.76
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=413.56
# 📊 Vehicles per zone (average): min=0.0, max=217.25, var=416.33
# 📊 Vehicles per zone (average): min=0.0, max=215.25, var=409.51
# 📊 Vehicles per zone (average): min=0.0, max=215.5, var=404.79
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=415.09
# 📊 Vehicles per zone (average): min=0.0, max=217.75, var=405.93
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=434.10
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=442.03
# 📊 Vehicles per zone (average): min=0.0, max=221.75, var=431.18
# 📊 Vehicles per zone (average): min=0.0, max=222.0, var=433.41
# 📊 Vehicles per zone (average): min=0.0, max=216.5, var=404.27
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=407.64
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=417.93
# 📊 Vehicles per zone (average): min=0.0, max=218.0, var=417.79
# 📊 Vehicles per zone (average): min=0.0, max=220.5, var=421.76
# 📊 Vehicles per zone (average): min=0.0, max=223.75, var=432.54
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=440.09
# 📊 Vehicles per zone (average): min=0.0, max=218.75, var=415.89
# 📊 Vehicles per zone (average): min=0.0, max=217.0, var=418.41
# 📊 Vehicles per zone (average): min=0.0, max=214.25, var=400.94
# 📊 Vehicles per zone (average): min=0.0, max=222.0, var=425.21
# 📊 Vehicles per zone (average): min=0.0, max=215.75, var=399.44
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=427.66
# 📊 Vehicles per zone (average): min=0.0, max=215.0, var=405.65
# 📊 Vehicles per zone (average): min=0.0, max=216.75, var=423.18
# 📊 Calculating PT+DRT vehicles per zone... (eval #1800)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 9945.0
# 📊 Vehicles per zone (average): min=0.0, max=222.5, var=426.20
#    📊 Evaluation summary:
#       Best objective: 387.8956
#       Worst objective: 456.9532
#       Average objective: 417.4704
#       Feasible solutions: 60/60
#     30 |     1800 | -1.9E-02 |       3 |  0.3884 |  1.74599 |  2.27424 |  0.000000E+00 |  0.000000E+00 |  4.092770E+02 |  3.878956E+02
#
# ✅ OPTIMIZATION COMPLETED
#    Best objective: 387.895621
#    Generations: 30
#    Time: 24.4s
#    Avg time/gen: 0.813s
#    Best feasible solutions tracked: 3
#    ✅ All constraints satisfied
#
# ✅ BASELINE OPTIMIZATION COMPLETE:
#    Best objective: 387.895621
#    Runtime: 24.4s
#
# 📈 COMPARISON:
#    Improvement with seeding: +2.72%
#    Time difference: +0.5s

# %% [markdown]
# ### Option 2: Running PSO with multiple initial solutions
#
# The main difference here is that in the `sampling` config, we provide a List object instead of `from_data`. As shown above, this list is created by loading in multiple solutions from disk using `extract_multiple_gtfs_solutions`

# %%
# Configuration with solution list seeding
config_with_solution_list = {
    'problem': {
        'objective': {
            'type': 'HexagonalCoverageObjective',
            'spatial_resolution_km': 2.0,
            'boundary': study_boundary,
            'crs': 'EPSG:3857',
            'time_aggregation': 'average'
        },
        'constraints': [
            {
                'type': 'FleetTotalConstraintHandler',
                'baseline': 'current_peak',
                'tolerance': 0.30,
                'measure': 'peak'
            }
        ]
    },
    'optimization': {
        'algorithm': {
            'type': 'PSO',
            'pop_size': 60,
            'inertia_weight': 0.9,
            'cognitive_coeff': 2.0,
            'social_coeff': 2.0,
            'adaptive': True
        },
        'sampling': {
            'enabled': True,
            'base_solutions': flat_solutions_from_files,  # Use loaded solutions directly
            'frac_gaussian_pert': 0.2,
            'gaussian_sigma': 1.5,
            'random_seed': 123
        },
        'termination': {
            'max_generations': 30
        },
        'monitoring': {
            'progress_frequency': 5,
            'save_history': True
        }
    }
}

print("\n🚀 RUNNING PSO WITH SOLUTION LIST SEEDING:")
print(f"   Base solutions: {len(flat_solutions_from_files)}")
print(f"   Population size: 30")
print(f"   Seeding: 60% Gaussian + 40% LHS")

config_manager_list = OptimizationConfigManager(config_dict=config_with_solution_list)
runner_list = PSORunner(config_manager_list)

result_from_list = runner_list.optimize(opt_data, track_best_n=3)

print(f"\n✅ OPTIMIZATION WITH SOLUTION LIST SEEDING COMPLETE:")
print(f"   Best objective: {result_from_list.best_objective:.6f}")
print(f"   Runtime: {result_from_list.optimization_time:.1f}s")
print(f"   Generations: {result_from_list.generations_completed}")
print(f"   Feasible: {result_from_list.constraint_violations['feasible']}")
# Out:
# 🚀 RUNNING PSO WITH SOLUTION LIST SEEDING:
#    Base solutions: 3
#    Population size: 30
#    Seeding: 60% Gaussian + 40% LHS
# 📋 Using provided configuration dictionary
# 🚀 STARTING PSO OPTIMIZATION
# 🗺️ Setting up spatial analysis with 2.0km resolution
# 🗺️  Reprojected 6897 stops to EPSG:3857
# 🎯 Applying boundary filter to 6897 stops...
# 🔍 Filtered 6897 → 4405 points
# ✅ Filtered to 4405 stops within boundary
# 🔧 Creating 27 × 26 = 702 grid cells
#    Grid bounds: (-195346, 7111759) to (-142657, 7161976) meters
#    Cell size: 2000.0m × 2000.0m
# ✅ Created 702 hexagonal zones in EPSG:3857
# 🎯 Applying boundary filter to 702 grid cells...
# 🔍 Filtered 702 → 552 grid cells
# ✅ Filtered to 552 grid cells within boundary
# 🚀 Using spatial join for zone mapping...
# ✅ Mapped 4405 stops to zones
# 🗺️ Computing DRT spatial intersections for 2 zones...
#    Hexagonal grid size: 552 zones
#    Zone drt_ne: affects 149 hexagonal zones
#    Zone drt_nw: affects 54 hexagonal zones
# 🚀 Pre-computing route-stop mappings...
# ✅ Cached stops for 187 routes
# ✅ Spatial system ready: 552 hexagonal zones
#    📋 Creating 1 constraint handler(s)...
#       Creating constraint 1: FleetTotalConstraintHandler
#          ✓ FleetTotal: 1 constraint(s)
# 🏗️  CREATING TRANSIT OPTIMIZATION PROBLEM:
#    📊 Problem dimensions (PT+DRT):
#       PT Routes: 147
#       DRT Zones: 2
#       Time intervals: 4
#       PT Headway choices: 7
#    🔧 Pymoo parameters:
#       Decision variables: 596
#       Objectives: 1
#       Constraints: 1
#       Total variables: 596
#       PT variables: 588
#       DRT variables: 8
#    🚦 Hard constraints: 1 constraint(s)
#    📋 Constraint breakdown:
#       1. FleetTotalConstraintHandler: 1 constraint(s)
#    ✅ Problem setup complete!
# ✅ Problem created successfully:
#    📊 Variables: 596
#    🚦 Total constraints: 1 (from 1 handler(s))
#    🎯 Objective: HexagonalCoverageObjective
#    📋 Constraint types: ['FleetTotalConstraintHandler']
#    🎯 Method: Hard constraints
# 🔧 Creating custom initial population...
# 🔧 Building initial population (size=60):
#    🎲 Random seed set to: 123
#    📋 Base solution 1: shape (596,)
#    📋 Base solution 2: shape (596,)
#    📋 Base solution 3: shape (596,)
#    ✅ Loaded 3 base solutions
#    📊 Population distribution:
#       Base solutions: 3
#       Gaussian perturbations: 12
#       LHS samples: 45
#    ✅ Final population shape: (60, 596)
#    🎯 Ready for PSO algorithm
# ✅ Custom population set: shape (60, 596)
#    📊 Gaussian fraction: 20.0%
#    📊 LHS fraction: 80.0% (calculated)
#
# 📋 OPTIMIZATION CONFIGURATION:
#    Algorithm: PSO (adaptive)
#    Population size: 60
#    Initial parameters: w=0.9, c1=2.0, c2=2.0
#    Adaptation: PyMOO adjusts parameters based on swarm diversity
#    Max generations: 30
#    Problem size: 596 variables, 1 constraints
#
# 📊 Running optimization (pymoo will show progress)...
# 📊 Calculating PT+DRT vehicles per zone... (eval #1)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 17380.0
# 📊 Vehicles per zone (average): min=0.0, max=367.75, var=1212.84
# 📊 Vehicles per zone (average): min=0.0, max=366.5, var=1214.18
# 📊 Vehicles per zone (average): min=0.0, max=369.5, var=1215.83
# 📊 Vehicles per zone (average): min=0.0, max=409.75, var=1569.28
# 📊 Vehicles per zone (average): min=0.0, max=435.5, var=1754.74
# 📊 Vehicles per zone (average): min=0.0, max=410.75, var=1567.78
# 📊 Vehicles per zone (average): min=0.0, max=394.75, var=1370.39
# 📊 Vehicles per zone (average): min=0.0, max=431.5, var=1636.93
# 📊 Vehicles per zone (average): min=0.0, max=402.25, var=1418.30
# 📊 Vehicles per zone (average): min=0.0, max=421.0, var=1513.54
# 📊 Vehicles per zone (average): min=0.0, max=402.75, var=1454.92
# 📊 Vehicles per zone (average): min=0.0, max=410.0, var=1511.25
# 📊 Vehicles per zone (average): min=0.0, max=428.75, var=1681.98
# 📊 Vehicles per zone (average): min=0.0, max=407.75, var=1465.41
# 📊 Vehicles per zone (average): min=0.0, max=425.0, var=1633.94
# 📊 Vehicles per zone (average): min=0.0, max=326.75, var=1103.20
# 📊 Vehicles per zone (average): min=0.0, max=323.25, var=1585.01
# 📊 Vehicles per zone (average): min=0.0, max=329.25, var=1474.31
# 📊 Vehicles per zone (average): min=0.0, max=376.5, var=1193.82
# 📊 Vehicles per zone (average): min=0.0, max=328.25, var=1289.34
# 📊 Vehicles per zone (average): min=0.0, max=333.25, var=1105.13
# 📊 Vehicles per zone (average): min=0.0, max=338.5, var=1179.68
# 📊 Vehicles per zone (average): min=0.0, max=341.25, var=1468.13
# 📊 Vehicles per zone (average): min=0.0, max=353.75, var=1264.35
# 📊 Vehicles per zone (average): min=0.0, max=327.5, var=1434.66
# 📊 Vehicles per zone (average): min=0.0, max=349.75, var=1183.45
# 📊 Vehicles per zone (average): min=0.0, max=368.5, var=1194.01
# 📊 Vehicles per zone (average): min=0.0, max=360.5, var=1476.49
# 📊 Vehicles per zone (average): min=0.0, max=324.75, var=979.85
# 📊 Vehicles per zone (average): min=0.0, max=342.5, var=1846.91
# 📊 Vehicles per zone (average): min=0.0, max=352.25, var=1261.27
# 📊 Vehicles per zone (average): min=0.0, max=314.75, var=902.93
# 📊 Vehicles per zone (average): min=0.0, max=354.25, var=1359.66
# 📊 Vehicles per zone (average): min=0.0, max=337.0, var=1155.73
# 📊 Vehicles per zone (average): min=0.0, max=351.25, var=1515.80
# 📊 Vehicles per zone (average): min=0.0, max=336.5, var=1360.92
# 📊 Vehicles per zone (average): min=0.0, max=361.75, var=1244.66
# 📊 Vehicles per zone (average): min=0.0, max=318.25, var=1084.29
# 📊 Vehicles per zone (average): min=0.0, max=329.25, var=1701.10
# 📊 Vehicles per zone (average): min=0.0, max=370.5, var=1248.78
# 📊 Vehicles per zone (average): min=0.0, max=366.5, var=1425.96
# 📊 Vehicles per zone (average): min=0.0, max=294.25, var=874.02
# 📊 Vehicles per zone (average): min=0.0, max=339.25, var=1481.96
# 📊 Vehicles per zone (average): min=0.0, max=358.25, var=1677.23
# 📊 Vehicles per zone (average): min=0.0, max=356.75, var=1199.28
# 📊 Vehicles per zone (average): min=0.0, max=325.75, var=911.90
# 📊 Vehicles per zone (average): min=0.0, max=348.5, var=1193.62
# 📊 Vehicles per zone (average): min=0.0, max=340.25, var=1427.75
# 📊 Vehicles per zone (average): min=0.0, max=360.0, var=1362.53
# 📊 Calculating PT+DRT vehicles per zone... (eval #50)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 23298.0
# 📊 Vehicles per zone (average): min=0.0, max=340.0, var=1489.50
# 📊 Vehicles per zone (average): min=0.0, max=376.5, var=1520.76
# 📊 Vehicles per zone (average): min=0.0, max=325.5, var=1333.50
# 📊 Vehicles per zone (average): min=0.0, max=352.25, var=1175.78
# 📊 Vehicles per zone (average): min=0.0, max=356.75, var=1557.32
# 📊 Vehicles per zone (average): min=0.0, max=353.75, var=1365.85
# 📊 Vehicles per zone (average): min=0.0, max=356.75, var=1781.58
# 📊 Vehicles per zone (average): min=0.0, max=330.25, var=1278.80
# 📊 Vehicles per zone (average): min=0.0, max=307.0, var=1823.45
# 📊 Vehicles per zone (average): min=0.0, max=343.5, var=1206.44
# 📊 Vehicles per zone (average): min=0.0, max=340.0, var=1549.44
#    📊 Evaluation summary:
#       Best objective: 874.0230
#       Worst objective: 1846.9064
#       Average objective: 1374.5244
#       Feasible solutions: 60/60
# ======================================================================================================================================
# n_gen  |  n_eval  |    f     |    S    |    w    |    c1    |    c2    |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ======================================================================================================================================
#      1 |       60 |        - |       - |  0.9000 |  2.00000 |  2.00000 |  0.000000E+00 |  0.000000E+00 |  1.374524E+03 |  8.740230E+02
# 📊 Vehicles per zone (average): min=0.0, max=277.5, var=740.32
# 📊 Vehicles per zone (average): min=0.0, max=289.75, var=772.23
# 📊 Vehicles per zone (average): min=0.0, max=294.25, var=792.38
# 📊 Vehicles per zone (average): min=0.0, max=315.25, var=947.27
# 📊 Vehicles per zone (average): min=0.0, max=325.0, var=1050.82
# 📊 Vehicles per zone (average): min=0.0, max=303.75, var=945.45
# 📊 Vehicles per zone (average): min=0.0, max=302.75, var=846.95
# 📊 Vehicles per zone (average): min=0.0, max=323.25, var=975.91
# 📊 Vehicles per zone (average): min=0.0, max=300.5, var=832.23
# 📊 Vehicles per zone (average): min=0.0, max=318.5, var=934.39
# 📊 Vehicles per zone (average): min=0.0, max=303.5, var=857.26
# 📊 Vehicles per zone (average): min=0.0, max=299.5, var=880.23
# 📊 Vehicles per zone (average): min=0.0, max=312.0, var=891.30
# 📊 Vehicles per zone (average): min=0.0, max=310.25, var=847.42
# 📊 Vehicles per zone (average): min=0.0, max=326.25, var=1068.16
# 📊 Vehicles per zone (average): min=0.0, max=256.75, var=679.64
# 📊 Vehicles per zone (average): min=0.0, max=266.5, var=922.98
# 📊 Vehicles per zone (average): min=0.0, max=260.25, var=815.31
# 📊 Vehicles per zone (average): min=0.0, max=286.5, var=734.32
# 📊 Vehicles per zone (average): min=0.0, max=249.0, var=763.76
# 📊 Vehicles per zone (average): min=0.0, max=265.0, var=982.05
# 📊 Vehicles per zone (average): min=0.0, max=261.75, var=744.99
# 📊 Vehicles per zone (average): min=0.0, max=264.75, var=901.70
# 📊 Vehicles per zone (average): min=0.0, max=277.0, var=982.23
# 📊 Vehicles per zone (average): min=0.0, max=263.5, var=799.65
# 📊 Vehicles per zone (average): min=0.0, max=283.5, var=808.26
# 📊 Vehicles per zone (average): min=0.0, max=270.25, var=787.94
# 📊 Vehicles per zone (average): min=0.0, max=272.5, var=889.83
# 📊 Vehicles per zone (average): min=0.0, max=251.5, var=661.00
# 📊 Vehicles per zone (average): min=0.0, max=264.5, var=911.26
# 📊 Vehicles per zone (average): min=0.0, max=270.0, var=770.97
# 📊 Vehicles per zone (average): min=0.0, max=251.25, var=632.10
# 📊 Vehicles per zone (average): min=0.0, max=270.25, var=817.88
# 📊 Vehicles per zone (average): min=0.0, max=259.5, var=822.26
# 📊 Vehicles per zone (average): min=0.0, max=276.75, var=811.04
# 📊 Vehicles per zone (average): min=0.0, max=268.0, var=974.63
# 📊 Vehicles per zone (average): min=0.0, max=275.0, var=851.07
# 📊 Vehicles per zone (average): min=0.0, max=249.25, var=671.34
# 📊 Vehicles per zone (average): min=0.0, max=261.5, var=858.17
# 📊 Calculating PT+DRT vehicles per zone... (eval #100)
# 🔍 System peak analysis:
#    Peak interval: 0 (00-06h)
#    Peak total vehicles: 14878.0
# 📊 Vehicles per zone (average): min=0.0, max=287.0, var=808.38
# 📊 Vehicles per zone (average): min=0.0, max=285.0, var=842.22
# 📊 Vehicles per zone (average): min=0.0, max=294.25, var=874.02
# 📊 Vehicles per zone (average): min=0.0, max=261.75, var=862.29
# 📊 Vehicles per zone (average): min=0.0, max=266.0, var=937.03
# 📊 Vehicles per zone (average): min=0.0, max=271.75, var=711.24
# 📊 Vehicles per zone (average): min=0.0, max=256.0, var=697.33
# 📊 Vehicles per zone (average): min=0.0, max=272.5, var=982.87
# 📊 Vehicles per zone (average): min=0.0, max=269.0, var=840.98
# 📊 Vehicles per zone (average): min=0.0, max=271.25, var=842.64
# 📊 Vehicles per zone (average): min=0.0, max=261.25, var=783.18
# 📊 Vehicles per zone (average): min=0.0, max=287.0, var=1004.02
# 📊 Vehicles per zone (average): min=0.0, max=256.75, var=729.05
# 📊 Vehicles per zone (average): min=0.0, max=269.25, var=700.57
# 📊 Vehicles per zone (average): min=0.0, max=281.75, var=967.27
# 📊 Vehicles per zone (average): min=0.0, max=276.25, var=804.81
# 📊 Vehicles per zone (average): min=0.0, max=276.5, var=1091.58
# 📊 Vehicles per zone (average): min=0.0, max=256.75, var=746.18
# 📊 Vehicles per zone (average): min=0.0, max=241.25, var=812.91
# 📊 Vehicles per zone (average): min=0.0, max=263.5, var=780.22
# 📊 Vehicles per zone (average): min=0.0, max=275.0, var=829.04
#    📊 Evaluation summary:
#       Best objective: 632.0981
#       Worst objective: 1091.5770
#       Average objective: 843.7415
#       Feasible solutions: 60/60
#      2 |      120 |  0.62230 |       1 |  0.7707 |  2.07950 |  1.92050 |  0.000000E+00 |  0.000000E+00 |  8.437415E+02 |  6.320981E+02
# 📊 Vehicles per zone (average): min=0.0, max=246.75, var=643.66
# 📊 Vehicles per zone (average): min=0.0, max=247.5, var=649.32
# 📊 Vehicles per zone (average): min=0.0, max=252.0, var=602.48
# 📊 Vehicles per zone (average): min=0.0, max=254.5, var=618.70
# 📊 Vehicles per zone (average): min=0.0, max=246.5, var=590.50
# 📊 Vehicles per zone (average): min=0.0, max=246.75, var=584.90
# 📊 Vehicles per zone (average): min=0.0, max=251.25, var=594.48
# 📊 Vehicles per zone (average): min=0.0, max=242.0, var=598.40
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=573.02
# 📊 Vehicles per zone (average): min=0.0, max=249.0, var=633.60
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=593.80
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=655.05
# 📊 Vehicles per zone (average): min=0.0, max=248.5, var=588.11
# 📊 Vehicles per zone (average): min=0.0, max=251.75, var=576.10
# 📊 Vehicles per zone (average): min=0.0, max=256.0, var=729.99
# 📊 Vehicles per zone (average): min=0.0, max=229.0, var=506.95
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=664.65
# 📊 Vehicles per zone (average): min=0.0, max=242.25, var=554.72
# 📊 Vehicles per zone (average): min=0.0, max=243.25, var=688.92
# 📊 Vehicles per zone (average): min=0.0, max=216.75, var=491.13
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=724.02
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=577.15
# 📊 Vehicles per zone (average): min=0.0, max=221.75, var=635.38
# 📊 Vehicles per zone (average): min=0.0, max=235.25, var=585.93
# 📊 Vehicles per zone (average): min=0.0, max=228.5, var=581.62
# 📊 Vehicles per zone (average): min=0.0, max=247.5, var=750.45
# 📊 Vehicles per zone (average): min=0.0, max=227.5, var=548.46
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=683.24
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=487.27
# 📊 Calculating PT+DRT vehicles per zone... (eval #150)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 15161.0
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=547.88
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=622.00
# 📊 Vehicles per zone (average): min=0.0, max=251.25, var=632.10
# 📊 Vehicles per zone (average): min=0.0, max=233.25, var=577.80
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=660.09
# 📊 Vehicles per zone (average): min=0.0, max=247.75, var=587.69
# 📊 Vehicles per zone (average): min=0.0, max=239.75, var=719.89
# 📊 Vehicles per zone (average): min=0.0, max=240.0, var=662.84
# 📊 Vehicles per zone (average): min=0.0, max=237.5, var=543.16
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=615.32
# 📊 Vehicles per zone (average): min=0.0, max=239.5, var=589.62
# 📊 Vehicles per zone (average): min=0.0, max=238.75, var=587.37
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=546.47
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=729.21
# 📊 Vehicles per zone (average): min=0.0, max=227.0, var=631.21
# 📊 Vehicles per zone (average): min=0.0, max=236.5, var=523.88
# 📊 Vehicles per zone (average): min=0.0, max=229.75, var=543.84
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=604.39
# 📊 Vehicles per zone (average): min=0.0, max=240.0, var=713.61
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=544.63
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=560.41
# 📊 Vehicles per zone (average): min=0.0, max=233.5, var=665.76
# 📊 Vehicles per zone (average): min=0.0, max=230.25, var=532.84
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=603.33
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=623.24
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=566.36
# 📊 Vehicles per zone (average): min=0.0, max=236.75, var=617.09
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=502.53
# 📊 Vehicles per zone (average): min=0.0, max=226.0, var=533.82
# 📊 Vehicles per zone (average): min=0.0, max=235.5, var=619.41
# 📊 Vehicles per zone (average): min=0.0, max=242.0, var=607.84
#    📊 Evaluation summary:
#       Best objective: 487.2690
#       Worst objective: 750.4483
#       Average objective: 605.4605
#       Feasible solutions: 60/60
#      3 |      180 |  0.66439 |       1 |  0.7895 |  2.16060 |  1.83940 |  0.000000E+00 |  0.000000E+00 |  6.054605E+02 |  4.872690E+02
# 📊 Vehicles per zone (average): min=0.0, max=222.0, var=581.60
# 📊 Vehicles per zone (average): min=0.0, max=222.75, var=580.69
# 📊 Vehicles per zone (average): min=0.0, max=223.0, var=584.58
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=582.23
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=476.04
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=560.68
# 📊 Vehicles per zone (average): min=0.0, max=224.25, var=583.17
# 📊 Vehicles per zone (average): min=0.0, max=212.0, var=480.95
# 📊 Vehicles per zone (average): min=0.0, max=219.5, var=583.24
# 📊 Vehicles per zone (average): min=0.0, max=221.0, var=627.48
# 📊 Vehicles per zone (average): min=0.0, max=223.25, var=632.38
# 📊 Vehicles per zone (average): min=0.0, max=216.0, var=521.42
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=483.49
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=549.06
# 📊 Vehicles per zone (average): min=0.0, max=231.25, var=588.31
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=524.43
# 📊 Vehicles per zone (average): min=0.0, max=230.75, var=666.42
# 📊 Vehicles per zone (average): min=0.0, max=236.25, var=539.16
# 📊 Vehicles per zone (average): min=0.0, max=241.25, var=641.97
# 📊 Calculating PT+DRT vehicles per zone... (eval #200)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 11660.0
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=508.09
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=601.75
# 📊 Vehicles per zone (average): min=0.0, max=238.0, var=558.19
# 📊 Vehicles per zone (average): min=0.0, max=224.5, var=636.29
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=540.62
# 📊 Vehicles per zone (average): min=0.0, max=233.0, var=689.82
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=634.40
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=575.33
# 📊 Vehicles per zone (average): min=0.0, max=235.75, var=667.36
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=487.27
# 📊 Vehicles per zone (average): min=0.0, max=227.5, var=512.40
# 📊 Vehicles per zone (average): min=0.0, max=243.0, var=659.41
# 📊 Vehicles per zone (average): min=0.0, max=220.0, var=515.95
# 📊 Vehicles per zone (average): min=0.0, max=240.25, var=604.75
# 📊 Vehicles per zone (average): min=0.0, max=234.25, var=626.88
# 📊 Vehicles per zone (average): min=0.0, max=246.5, var=588.17
# 📊 Vehicles per zone (average): min=0.0, max=231.0, var=641.12
# 📊 Vehicles per zone (average): min=0.0, max=231.5, var=584.16
# 📊 Vehicles per zone (average): min=0.0, max=238.0, var=602.69
# 📊 Vehicles per zone (average): min=0.0, max=229.5, var=623.80
# 📊 Vehicles per zone (average): min=0.0, max=235.0, var=558.34
# 📊 Vehicles per zone (average): min=0.0, max=225.75, var=477.31
# 📊 Vehicles per zone (average): min=0.0, max=187.25, var=440.21
# 📊 Vehicles per zone (average): min=0.0, max=228.5, var=622.40
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=543.14
# 📊 Vehicles per zone (average): min=0.0, max=234.0, var=531.05
# 📊 Vehicles per zone (average): min=0.0, max=237.75, var=562.44
# 📊 Vehicles per zone (average): min=0.0, max=237.0, var=598.63
# 📊 Vehicles per zone (average): min=0.0, max=238.25, var=632.75
# 📊 Vehicles per zone (average): min=0.0, max=221.5, var=529.20
# 📊 Vehicles per zone (average): min=0.0, max=236.0, var=553.72
# 📊 Vehicles per zone (average): min=0.0, max=230.5, var=584.59
# 📊 Vehicles per zone (average): min=0.0, max=230.0, var=513.57
# 📊 Vehicles per zone (average): min=0.0, max=229.25, var=600.46
# 📊 Vehicles per zone (average): min=0.0, max=234.5, var=548.52
# 📊 Vehicles per zone (average): min=0.0, max=232.5, var=555.67
# 📊 Vehicles per zone (average): min=0.0, max=222.25, var=548.36
# 📊 Vehicles per zone (average): min=0.0, max=232.75, var=601.52
# 📊 Vehicles per zone (average): min=0.0, max=240.5, var=593.24
# 📊 Vehicles per zone (average): min=0.0, max=234.75, var=653.98
# 📊 Vehicles per zone (average): min=0.0, max=232.25, var=601.43
#    📊 Evaluation summary:
#       Best objective: 440.2146
#       Worst objective: 689.8248
#       Average objective: 574.9379
#       Feasible solutions: 60/60
#      4 |      240 |  0.00751 |       3 |  0.4047 |  2.15733 |  1.86309 |  0.000000E+00 |  0.000000E+00 |  5.653946E+02 |  4.402146E+02
# 📊 Vehicles per zone (average): min=0.0, max=199.75, var=533.26
# 📊 Vehicles per zone (average): min=0.0, max=201.25, var=439.95
# 📊 Vehicles per zone (average): min=0.0, max=198.25, var=643.18
# 📊 Vehicles per zone (average): min=0.0, max=207.25, var=561.50
# 📊 Vehicles per zone (average): min=0.0, max=202.25, var=468.83
# 📊 Vehicles per zone (average): min=0.0, max=200.5, var=475.54
# 📊 Vehicles per zone (average): min=0.0, max=201.0, var=551.36
# 📊 Vehicles per zone (average): min=0.0, max=193.75, var=577.71
# 📊 Vehicles per zone (average): min=0.0, max=206.75, var=458.29
# 📊 Calculating PT+DRT vehicles per zone... (eval #250)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 14097.0
# 📊 Vehicles per zone (average): min=0.0, max=193.0, var=449.77
# 📊 Vehicles per zone (average): min=0.0, max=211.75, var=486.33
# 📊 Vehicles per zone (average): min=0.0, max=189.25, var=516.72
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=440.56
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=627.27
# 📊 Vehicles per zone (average): min=0.0, max=202.5, var=591.59
# 📊 Vehicles per zone (average): min=0.0, max=213.5, var=531.35
# 📊 Vehicles per zone (average): min=0.0, max=206.0, var=495.66
# 📊 Vehicles per zone (average): min=0.0, max=207.25, var=536.48
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=604.22
# 📊 Vehicles per zone (average): min=0.0, max=197.75, var=506.78
# 📊 Vehicles per zone (average): min=0.0, max=208.25, var=541.18
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=465.12
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=568.44
# 📊 Vehicles per zone (average): min=0.0, max=215.0, var=550.28
# 📊 Vehicles per zone (average): min=0.0, max=207.5, var=539.51
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=510.19
# 📊 Vehicles per zone (average): min=0.0, max=210.5, var=478.83
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=519.55
# 📊 Vehicles per zone (average): min=0.0, max=201.25, var=500.34
# 📊 Vehicles per zone (average): min=0.0, max=211.0, var=452.32
# 📊 Vehicles per zone (average): min=0.0, max=215.0, var=561.28
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=553.14
# 📊 Vehicles per zone (average): min=0.0, max=200.5, var=462.00
# 📊 Vehicles per zone (average): min=0.0, max=218.5, var=566.81
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=504.81
# 📊 Vehicles per zone (average): min=0.0, max=209.75, var=538.33
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=537.61
# 📊 Vehicles per zone (average): min=0.0, max=208.0, var=567.01
# 📊 Vehicles per zone (average): min=0.0, max=205.5, var=488.35
# 📊 Vehicles per zone (average): min=0.0, max=204.5, var=526.30
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=399.35
# 📊 Vehicles per zone (average): min=0.0, max=187.25, var=440.21
# 📊 Vehicles per zone (average): min=0.0, max=202.75, var=518.47
# 📊 Vehicles per zone (average): min=0.0, max=211.5, var=478.41
# 📊 Vehicles per zone (average): min=0.0, max=213.5, var=469.68
# 📊 Vehicles per zone (average): min=0.0, max=214.0, var=502.24
# 📊 Vehicles per zone (average): min=0.0, max=213.75, var=511.16
# 📊 Vehicles per zone (average): min=0.0, max=212.5, var=516.21
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=432.74
# 📊 Vehicles per zone (average): min=0.0, max=209.5, var=475.92
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=579.54
# 📊 Vehicles per zone (average): min=0.0, max=204.25, var=529.38
# 📊 Vehicles per zone (average): min=0.0, max=205.5, var=493.81
# 📊 Vehicles per zone (average): min=0.0, max=203.0, var=455.27
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=440.13
# 📊 Vehicles per zone (average): min=0.0, max=201.25, var=433.36
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=524.14
# 📊 Vehicles per zone (average): min=0.0, max=195.25, var=500.92
# 📊 Vehicles per zone (average): min=0.0, max=218.25, var=591.34
# 📊 Calculating PT+DRT vehicles per zone... (eval #300)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 14110.0
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=473.48
#    📊 Evaluation summary:
#       Best objective: 399.3478
#       Worst objective: 643.1769
#       Average objective: 511.5587
#       Feasible solutions: 60/60
#      5 |      300 | -2.2E-02 |       3 |  0.3866 |  2.14438 |  1.87437 |  0.000000E+00 |  0.000000E+00 |  5.049241E+02 |  3.993478E+02
# 📊 Vehicles per zone (average): min=0.0, max=207.25, var=505.99
# 📊 Vehicles per zone (average): min=0.0, max=199.5, var=408.81
# 📊 Vehicles per zone (average): min=0.0, max=214.75, var=456.61
# 📊 Vehicles per zone (average): min=0.0, max=210.25, var=459.81
# 📊 Vehicles per zone (average): min=0.0, max=202.25, var=433.53
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=426.73
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=449.95
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=484.74
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=428.70
# 📊 Vehicles per zone (average): min=0.0, max=192.5, var=413.25
# 📊 Vehicles per zone (average): min=0.0, max=206.75, var=436.90
# 📊 Vehicles per zone (average): min=0.0, max=201.25, var=451.58
# 📊 Vehicles per zone (average): min=0.0, max=206.25, var=429.43
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=446.68
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=461.05
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=472.92
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=430.32
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=475.09
# 📊 Vehicles per zone (average): min=0.0, max=198.75, var=405.74
# 📊 Vehicles per zone (average): min=0.0, max=209.0, var=451.53
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=425.59
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=450.14
# 📊 Vehicles per zone (average): min=0.0, max=198.75, var=424.03
# 📊 Vehicles per zone (average): min=0.0, max=219.0, var=497.36
# 📊 Vehicles per zone (average): min=0.0, max=198.25, var=431.18
# 📊 Vehicles per zone (average): min=0.0, max=202.25, var=420.76
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=421.23
# 📊 Vehicles per zone (average): min=0.0, max=211.0, var=460.10
# 📊 Vehicles per zone (average): min=0.0, max=215.5, var=456.13
# 📊 Vehicles per zone (average): min=0.0, max=210.5, var=473.16
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=431.73
# 📊 Vehicles per zone (average): min=0.0, max=211.0, var=453.21
# 📊 Vehicles per zone (average): min=0.0, max=193.0, var=442.15
# 📊 Vehicles per zone (average): min=0.0, max=202.75, var=445.39
# 📊 Vehicles per zone (average): min=0.0, max=203.0, var=449.96
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=456.53
# 📊 Vehicles per zone (average): min=0.0, max=203.25, var=433.18
# 📊 Vehicles per zone (average): min=0.0, max=214.75, var=465.07
# 📊 Vehicles per zone (average): min=0.0, max=203.25, var=468.88
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=498.33
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=399.35
# 📊 Vehicles per zone (average): min=0.0, max=199.25, var=429.33
# 📊 Vehicles per zone (average): min=0.0, max=204.25, var=420.68
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=423.31
# 📊 Vehicles per zone (average): min=0.0, max=213.25, var=430.60
# 📊 Vehicles per zone (average): min=0.0, max=205.25, var=417.55
# 📊 Vehicles per zone (average): min=0.0, max=209.0, var=459.91
# 📊 Vehicles per zone (average): min=0.0, max=200.75, var=444.85
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=407.63
# 📊 Calculating PT+DRT vehicles per zone... (eval #350)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 14000.0
# 📊 Vehicles per zone (average): min=0.0, max=202.5, var=456.44
# 📊 Vehicles per zone (average): min=0.0, max=209.5, var=449.12
# 📊 Vehicles per zone (average): min=0.0, max=216.25, var=448.51
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=449.27
# 📊 Vehicles per zone (average): min=0.0, max=200.0, var=415.87
# 📊 Vehicles per zone (average): min=0.0, max=200.5, var=403.00
# 📊 Vehicles per zone (average): min=0.0, max=204.25, var=426.70
# 📊 Vehicles per zone (average): min=0.0, max=214.75, var=445.84
# 📊 Vehicles per zone (average): min=0.0, max=196.0, var=424.70
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=449.01
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=434.76
#    📊 Evaluation summary:
#       Best objective: 399.3478
#       Worst objective: 505.9928
#       Average objective: 442.8314
#       Feasible solutions: 60/60
#      6 |      360 | -1.7E-02 |       3 |  0.3895 |  2.13184 |  1.89178 |  0.000000E+00 |  0.000000E+00 |  4.424211E+02 |  3.993478E+02
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=482.13
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=404.57
# 📊 Vehicles per zone (average): min=0.0, max=214.5, var=429.91
# 📊 Vehicles per zone (average): min=0.0, max=210.5, var=429.85
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=440.41
# 📊 Vehicles per zone (average): min=0.0, max=204.25, var=419.85
# 📊 Vehicles per zone (average): min=0.0, max=211.25, var=436.83
# 📊 Vehicles per zone (average): min=0.0, max=217.0, var=436.94
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=438.05
# 📊 Vehicles per zone (average): min=0.0, max=211.5, var=419.36
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=404.56
# 📊 Vehicles per zone (average): min=0.0, max=215.0, var=448.86
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=445.19
# 📊 Vehicles per zone (average): min=0.0, max=210.0, var=441.21
# 📊 Vehicles per zone (average): min=0.0, max=216.25, var=467.04
# 📊 Vehicles per zone (average): min=0.0, max=202.5, var=433.76
# 📊 Vehicles per zone (average): min=0.0, max=200.25, var=420.50
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=473.67
# 📊 Vehicles per zone (average): min=0.0, max=203.25, var=418.77
# 📊 Vehicles per zone (average): min=0.0, max=202.75, var=434.14
# 📊 Vehicles per zone (average): min=0.0, max=206.25, var=423.32
# 📊 Vehicles per zone (average): min=0.0, max=199.25, var=435.96
# 📊 Vehicles per zone (average): min=0.0, max=202.25, var=391.93
# 📊 Vehicles per zone (average): min=0.0, max=210.25, var=447.83
# 📊 Vehicles per zone (average): min=0.0, max=205.5, var=411.07
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=436.74
# 📊 Vehicles per zone (average): min=0.0, max=205.25, var=420.35
# 📊 Vehicles per zone (average): min=0.0, max=204.75, var=426.24
# 📊 Vehicles per zone (average): min=0.0, max=217.75, var=460.28
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=422.37
# 📊 Vehicles per zone (average): min=0.0, max=201.5, var=400.64
# 📊 Vehicles per zone (average): min=0.0, max=217.5, var=461.20
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=433.20
# 📊 Vehicles per zone (average): min=0.0, max=201.0, var=410.68
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=440.63
# 📊 Vehicles per zone (average): min=0.0, max=204.75, var=412.15
# 📊 Vehicles per zone (average): min=0.0, max=206.5, var=444.67
# 📊 Vehicles per zone (average): min=0.0, max=212.5, var=456.65
# 📊 Vehicles per zone (average): min=0.0, max=208.25, var=456.99
# 📊 Calculating PT+DRT vehicles per zone... (eval #400)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 14161.0
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=446.40
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=399.35
# 📊 Vehicles per zone (average): min=0.0, max=209.5, var=432.19
# 📊 Vehicles per zone (average): min=0.0, max=203.0, var=416.05
# 📊 Vehicles per zone (average): min=0.0, max=211.75, var=449.71
# 📊 Vehicles per zone (average): min=0.0, max=215.25, var=450.30
# 📊 Vehicles per zone (average): min=0.0, max=208.0, var=430.44
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=443.21
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=425.47
# 📊 Vehicles per zone (average): min=0.0, max=214.5, var=440.43
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=426.72
# 📊 Vehicles per zone (average): min=0.0, max=208.25, var=425.86
# 📊 Vehicles per zone (average): min=0.0, max=210.0, var=408.84
# 📊 Vehicles per zone (average): min=0.0, max=206.75, var=425.49
# 📊 Vehicles per zone (average): min=0.0, max=204.0, var=418.12
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=415.21
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=412.51
# 📊 Vehicles per zone (average): min=0.0, max=211.5, var=443.86
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=421.65
# 📊 Vehicles per zone (average): min=0.0, max=204.75, var=424.12
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=417.75
#    📊 Evaluation summary:
#       Best objective: 391.9304
#       Worst objective: 482.1260
#       Average objective: 431.5353
#       Feasible solutions: 60/60
#      7 |      420 | -1.6E-02 |       3 |  0.3898 |  2.11771 |  1.90178 |  0.000000E+00 |  0.000000E+00 |  4.281047E+02 |  3.919304E+02
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=431.53
# 📊 Vehicles per zone (average): min=0.0, max=215.75, var=454.86
# 📊 Vehicles per zone (average): min=0.0, max=211.0, var=416.30
# 📊 Vehicles per zone (average): min=0.0, max=216.5, var=446.46
# 📊 Vehicles per zone (average): min=0.0, max=208.5, var=417.72
# 📊 Vehicles per zone (average): min=0.0, max=212.25, var=423.90
# 📊 Vehicles per zone (average): min=0.0, max=210.5, var=417.45
# 📊 Vehicles per zone (average): min=0.0, max=210.25, var=412.46
# 📊 Vehicles per zone (average): min=0.0, max=193.0, var=395.03
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=411.90
# 📊 Vehicles per zone (average): min=0.0, max=209.5, var=414.05
# 📊 Vehicles per zone (average): min=0.0, max=211.75, var=420.89
# 📊 Vehicles per zone (average): min=0.0, max=203.25, var=440.09
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=410.23
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=424.28
# 📊 Vehicles per zone (average): min=0.0, max=204.25, var=410.09
# 📊 Vehicles per zone (average): min=0.0, max=205.25, var=410.69
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=422.73
# 📊 Vehicles per zone (average): min=0.0, max=197.75, var=384.15
# 📊 Vehicles per zone (average): min=0.0, max=206.5, var=412.63
# 📊 Vehicles per zone (average): min=0.0, max=213.0, var=443.51
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=423.43
# 📊 Vehicles per zone (average): min=0.0, max=202.25, var=395.48
# 📊 Vehicles per zone (average): min=0.0, max=203.0, var=393.24
# 📊 Vehicles per zone (average): min=0.0, max=206.5, var=409.92
# 📊 Vehicles per zone (average): min=0.0, max=193.75, var=385.07
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=398.36
# 📊 Vehicles per zone (average): min=0.0, max=206.25, var=417.43
# 📊 Vehicles per zone (average): min=0.0, max=204.75, var=430.28
# 📊 Calculating PT+DRT vehicles per zone... (eval #450)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 12730.0
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=419.20
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=424.81
# 📊 Vehicles per zone (average): min=0.0, max=202.75, var=432.70
# 📊 Vehicles per zone (average): min=0.0, max=208.0, var=414.37
# 📊 Vehicles per zone (average): min=0.0, max=206.75, var=406.24
# 📊 Vehicles per zone (average): min=0.0, max=209.75, var=423.98
# 📊 Vehicles per zone (average): min=0.0, max=207.5, var=409.90
# 📊 Vehicles per zone (average): min=0.0, max=203.0, var=423.70
# 📊 Vehicles per zone (average): min=0.0, max=211.5, var=447.29
# 📊 Vehicles per zone (average): min=0.0, max=210.75, var=446.58
# 📊 Vehicles per zone (average): min=0.0, max=206.0, var=405.22
# 📊 Vehicles per zone (average): min=0.0, max=198.75, var=393.00
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=372.92
# 📊 Vehicles per zone (average): min=0.0, max=207.75, var=410.87
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=413.82
# 📊 Vehicles per zone (average): min=0.0, max=203.0, var=400.85
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=401.72
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=427.17
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=411.25
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=427.15
# 📊 Vehicles per zone (average): min=0.0, max=206.0, var=411.21
# 📊 Vehicles per zone (average): min=0.0, max=207.5, var=400.25
# 📊 Vehicles per zone (average): min=0.0, max=210.75, var=423.67
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=409.11
# 📊 Vehicles per zone (average): min=0.0, max=201.0, var=435.30
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=424.56
# 📊 Vehicles per zone (average): min=0.0, max=205.25, var=410.39
# 📊 Vehicles per zone (average): min=0.0, max=213.75, var=445.15
# 📊 Vehicles per zone (average): min=0.0, max=211.0, var=429.70
# 📊 Vehicles per zone (average): min=0.0, max=209.25, var=434.31
# 📊 Vehicles per zone (average): min=0.0, max=212.0, var=447.59
#    📊 Evaluation summary:
#       Best objective: 372.9155
#       Worst objective: 454.8570
#       Average objective: 417.6358
#       Feasible solutions: 60/60
#      8 |      480 | -2.2E-02 |       3 |  0.3864 |  2.10526 |  1.92010 |  0.000000E+00 |  0.000000E+00 |  4.132400E+02 |  3.729155E+02
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=403.47
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=404.60
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=410.23
# 📊 Vehicles per zone (average): min=0.0, max=201.0, var=403.92
# 📊 Vehicles per zone (average): min=0.0, max=199.5, var=396.87
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=387.86
# 📊 Vehicles per zone (average): min=0.0, max=198.25, var=387.50
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=394.38
# 📊 Vehicles per zone (average): min=0.0, max=195.25, var=378.26
# 📊 Vehicles per zone (average): min=0.0, max=201.25, var=437.66
# 📊 Vehicles per zone (average): min=0.0, max=199.25, var=387.14
# 📊 Vehicles per zone (average): min=0.0, max=202.75, var=401.47
# 📊 Vehicles per zone (average): min=0.0, max=205.0, var=426.25
# 📊 Vehicles per zone (average): min=0.0, max=199.5, var=394.57
# 📊 Vehicles per zone (average): min=0.0, max=193.75, var=371.28
# 📊 Vehicles per zone (average): min=0.0, max=205.25, var=418.36
# 📊 Vehicles per zone (average): min=0.0, max=204.75, var=401.34
# 📊 Vehicles per zone (average): min=0.0, max=190.75, var=367.35
# 📊 Vehicles per zone (average): min=0.0, max=199.25, var=386.86
# 📊 Calculating PT+DRT vehicles per zone... (eval #500)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 13073.0
# 📊 Vehicles per zone (average): min=0.0, max=202.0, var=410.90
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=429.11
# 📊 Vehicles per zone (average): min=0.0, max=203.25, var=394.63
# 📊 Vehicles per zone (average): min=0.0, max=200.5, var=388.36
# 📊 Vehicles per zone (average): min=0.0, max=189.75, var=362.92
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=403.22
# 📊 Vehicles per zone (average): min=0.0, max=194.0, var=390.67
# 📊 Vehicles per zone (average): min=0.0, max=200.25, var=390.49
# 📊 Vehicles per zone (average): min=0.0, max=205.75, var=410.46
# 📊 Vehicles per zone (average): min=0.0, max=191.25, var=404.60
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=412.15
# 📊 Vehicles per zone (average): min=0.0, max=199.5, var=442.68
# 📊 Vehicles per zone (average): min=0.0, max=198.75, var=419.35
# 📊 Vehicles per zone (average): min=0.0, max=199.25, var=394.42
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=393.50
# 📊 Vehicles per zone (average): min=0.0, max=200.5, var=394.53
# 📊 Vehicles per zone (average): min=0.0, max=200.5, var=404.56
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=386.76
# 📊 Vehicles per zone (average): min=0.0, max=208.5, var=425.23
# 📊 Vehicles per zone (average): min=0.0, max=213.25, var=429.13
# 📊 Vehicles per zone (average): min=0.0, max=203.75, var=402.09
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=406.16
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=372.92
# 📊 Vehicles per zone (average): min=0.0, max=204.75, var=405.83
# 📊 Vehicles per zone (average): min=0.0, max=202.5, var=402.87
# 📊 Vehicles per zone (average): min=0.0, max=202.75, var=405.39
# 📊 Vehicles per zone (average): min=0.0, max=191.75, var=367.10
# 📊 Vehicles per zone (average): min=0.0, max=200.25, var=392.50
# 📊 Vehicles per zone (average): min=0.0, max=203.5, var=403.14
# 📊 Vehicles per zone (average): min=0.0, max=204.5, var=424.92
# 📊 Vehicles per zone (average): min=0.0, max=201.5, var=394.93
# 📊 Vehicles per zone (average): min=0.0, max=199.5, var=385.94
# 📊 Vehicles per zone (average): min=0.0, max=204.5, var=407.31
# 📊 Vehicles per zone (average): min=0.0, max=208.75, var=415.00
# 📊 Vehicles per zone (average): min=0.0, max=194.0, var=407.71
# 📊 Vehicles per zone (average): min=0.0, max=195.25, var=401.72
# 📊 Vehicles per zone (average): min=0.0, max=200.0, var=391.70
# 📊 Vehicles per zone (average): min=0.0, max=199.25, var=408.33
# 📊 Vehicles per zone (average): min=0.0, max=198.25, var=379.37
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=406.47
# 📊 Vehicles per zone (average): min=0.0, max=199.5, var=383.85
#    📊 Evaluation summary:
#       Best objective: 362.9247
#       Worst objective: 442.6829
#       Average objective: 400.2054
#       Feasible solutions: 60/60
#      9 |      540 | -2.3E-02 |       3 |  0.3860 |  2.09045 |  1.93282 |  0.000000E+00 |  0.000000E+00 |  3.980204E+02 |  3.629247E+02
# 📊 Vehicles per zone (average): min=0.0, max=196.0, var=377.70
# 📊 Vehicles per zone (average): min=0.0, max=199.75, var=388.99
# 📊 Vehicles per zone (average): min=0.0, max=194.5, var=384.55
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=389.12
# 📊 Vehicles per zone (average): min=0.0, max=195.0, var=381.42
# 📊 Vehicles per zone (average): min=0.0, max=188.75, var=365.69
# 📊 Vehicles per zone (average): min=0.0, max=191.25, var=373.25
# 📊 Vehicles per zone (average): min=0.0, max=199.75, var=395.24
# 📊 Vehicles per zone (average): min=0.0, max=200.0, var=382.76
# 📊 Calculating PT+DRT vehicles per zone... (eval #550)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 13066.0
# 📊 Vehicles per zone (average): min=0.0, max=207.0, var=403.19
# 📊 Vehicles per zone (average): min=0.0, max=198.75, var=392.28
# 📊 Vehicles per zone (average): min=0.0, max=194.75, var=384.48
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=422.08
# 📊 Vehicles per zone (average): min=0.0, max=195.5, var=372.58
# 📊 Vehicles per zone (average): min=0.0, max=195.25, var=393.19
# 📊 Vehicles per zone (average): min=0.0, max=193.0, var=380.00
# 📊 Vehicles per zone (average): min=0.0, max=196.25, var=384.36
# 📊 Vehicles per zone (average): min=0.0, max=197.5, var=378.51
# 📊 Vehicles per zone (average): min=0.0, max=196.25, var=386.17
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=383.70
# 📊 Vehicles per zone (average): min=0.0, max=200.25, var=383.77
# 📊 Vehicles per zone (average): min=0.0, max=196.5, var=386.09
# 📊 Vehicles per zone (average): min=0.0, max=195.25, var=391.00
# 📊 Vehicles per zone (average): min=0.0, max=189.75, var=362.92
# 📊 Vehicles per zone (average): min=0.0, max=194.0, var=387.02
# 📊 Vehicles per zone (average): min=0.0, max=204.5, var=403.61
# 📊 Vehicles per zone (average): min=0.0, max=198.25, var=397.91
# 📊 Vehicles per zone (average): min=0.0, max=198.5, var=399.27
# 📊 Vehicles per zone (average): min=0.0, max=195.0, var=397.98
# 📊 Vehicles per zone (average): min=0.0, max=195.75, var=400.73
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=403.30
# 📊 Vehicles per zone (average): min=0.0, max=200.75, var=392.31
# 📊 Vehicles per zone (average): min=0.0, max=195.75, var=381.64
# 📊 Vehicles per zone (average): min=0.0, max=193.25, var=375.29
# 📊 Vehicles per zone (average): min=0.0, max=193.0, var=377.15
# 📊 Vehicles per zone (average): min=0.0, max=193.25, var=378.52
# 📊 Vehicles per zone (average): min=0.0, max=195.5, var=394.09
# 📊 Vehicles per zone (average): min=0.0, max=196.0, var=386.95
# 📊 Vehicles per zone (average): min=0.0, max=195.0, var=382.06
# 📊 Vehicles per zone (average): min=0.0, max=201.0, var=396.32
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=389.73
# 📊 Vehicles per zone (average): min=0.0, max=193.25, var=377.49
# 📊 Vehicles per zone (average): min=0.0, max=189.75, var=363.48
# 📊 Vehicles per zone (average): min=0.0, max=190.75, var=370.93
# 📊 Vehicles per zone (average): min=0.0, max=194.5, var=372.62
# 📊 Vehicles per zone (average): min=0.0, max=192.25, var=377.88
# 📊 Vehicles per zone (average): min=0.0, max=196.5, var=386.47
# 📊 Vehicles per zone (average): min=0.0, max=198.0, var=386.04
# 📊 Vehicles per zone (average): min=0.0, max=196.0, var=390.28
# 📊 Vehicles per zone (average): min=0.0, max=195.25, var=383.35
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=374.99
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=378.77
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=383.66
# 📊 Vehicles per zone (average): min=0.0, max=192.5, var=385.72
# 📊 Vehicles per zone (average): min=0.0, max=191.5, var=352.63
# 📊 Vehicles per zone (average): min=0.0, max=195.5, var=386.58
# 📊 Vehicles per zone (average): min=0.0, max=191.25, var=382.51
# 📊 Vehicles per zone (average): min=0.0, max=198.25, var=384.47
# 📊 Vehicles per zone (average): min=0.0, max=194.75, var=388.72
# 📊 Calculating PT+DRT vehicles per zone... (eval #600)
# 🔍 System peak analysis:
#    Peak interval: 1 (06-12h)
#    Peak total vehicles: 13009.0
# 📊 Vehicles per zone (average): min=0.0, max=191.75, var=370.22
#    📊 Evaluation summary:
#       Best objective: 352.6261
#       Worst objective: 422.0791
#       Average objective: 384.7291
#       Feasible solutions: 60/60
#     10 |      600 | -1.7E-02 |       3 |  0.3895 |  2.07668 |  1.95075 |  0.000000E+00 |  0.000000E+00 |  3.829852E+02 |  3.526261E+02
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=371.03
# 📊 Vehicles per zone (average): min=0.0, max=194.5, var=347.97
# 📊 Vehicles per zone (average): min=0.0, max=190.75, var=352.78
# 📊 Vehicles per zone (average): min=0.0, max=197.5, var=380.89
# 📊 Vehicles per zone (average): min=0.0, max=198.75, var=370.10
# 📊 Vehicles per zone (average): min=0.0, max=197.5, var=369.65
# 📊 Vehicles per zone (average): min=0.0, max=193.25, var=361.92
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=377.52
# 📊 Vehicles per zone (average): min=0.0, max=195.75, var=363.45
# 📊 Vehicles per zone (average): min=0.0, max=197.0, var=374.65
# 📊 Vehicles per zone (average): min=0.0, max=201.25, var=396.82
# 📊 Vehicles per zone (average): min=0.0, max=196.75, var=378.82
# 📊 Vehicles per zone (average): min=0.0, max=201.75, var=382.95
# 📊 Vehicles per zone (average): min=0.0, max=193.5, var=348.08
# 📊 Vehicles per zone (average): min=0.0, max=192.25, var=354.26
# 📊 Vehicles per zone (average): min=0.0, max=185.25, var=356.07
# 📊 Vehicles per zone (average): min=0.0, max=197.25, var=379.62
# 📊 Vehicles per zone (average): min=0.0, max=190.5, var=362.84
# 📊 Vehicles per zone (average): min=0.0, max=193.25, var=370.14
# 📊 Vehicles per zone (average): min=0.0, max=196.5, var=369.85
# 📊 Vehicles per zone (average): min=0.0, max=196.5, var=377.99
# 📊 Vehicles per zone (average): min=0.0, max=196.0, var=368.85
# 📊 Vehicles per zone (average): min=0.0, max=202.5, var=394.46
# 📊 Vehicles per zone (average): min=0.0, max=191.25, var=359.55
# 📊 Vehicles per zone (average): min=0.0, max=194.75, var=379.53
# 📊 Vehicles per zone (average): min=0.0, max=189.5, var=350.46
# 📊 Vehicles per zone (average): min=0.0, max=201.0, var=393.33
# 📊 Vehicles per zone (average): min=0.0, max=196.0, var=368.44
# 📊 Vehicles per zone (average): min=0.0, max=196.25, var=380.42
# 📊 Vehicles per zone (average): min=0.0, max=195.75, var=372.35
# 📊 Vehicles per zone (average): min=0.0, max=201.5, var=387.41
# 📊 Vehicles per zone (average): min=0.0, max=197.25, var=387.18
# 📊 Vehicles per zone (average): min=0.0, max=195.5, var=373.98
# 📊 Vehicles per zone (average): min=0.0, max=194.25, var=368.61
# 📊 Vehicles per zone (average): min=0.0, max=194.5, var=382.29
# 📊 Vehicles per zone (average): min=0.0, max=193.5, var=360.01
# 📊 Vehicles per zone (average): min=0.0, max=188.5, var=350.35
# 📊 Vehicles per zone (average): min=0.0, max=193.75, var=376.80
# 📊 Vehicles per zone (average): min=0.0, max=191.5, var=355.79
# 📊 Vehicles per zone (average): min=0.0, max=199.0, var=382.16
# 📊 Vehicles per zone (average): min=0.0, max=198.5, var=385.15
# ...
# 📊 Vehicles per zone (average): min=0.0, max=179.5, var=295.23
# 📊 Vehicles per zone (average): min=0.0, max=168.25, var=281.99
# 📊 Vehicles per zone (average): min=0.0, max=174.25, var=286.66
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=286.99
# 📊 Vehicles per zone (average): min=0.0, max=170.75, var=280.96
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=283.17
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=284.73
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=280.09
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=288.90
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=286.76
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=284.34
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=283.02
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=283.71
# 📊 Vehicles per zone (average): min=0.0, max=171.25, var=291.87
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=282.55
# 📊 Vehicles per zone (average): min=0.0, max=176.75, var=296.67
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=289.15
# 📊 Vehicles per zone (average): min=0.0, max=177.75, var=295.13
# 📊 Vehicles per zone (average): min=0.0, max=175.0, var=289.44
# 📊 Vehicles per zone (average): min=0.0, max=176.75, var=292.49
# 📊 Calculating PT+DRT vehicles per zone... (eval #1600)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 13084.0
# 📊 Vehicles per zone (average): min=0.0, max=178.25, var=305.77
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=275.46
# 📊 Vehicles per zone (average): min=0.0, max=166.5, var=274.47
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=288.16
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=287.68
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=285.59
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=291.63
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=287.84
# 📊 Vehicles per zone (average): min=0.0, max=177.75, var=303.22
# 📊 Vehicles per zone (average): min=0.0, max=175.75, var=293.11
# 📊 Vehicles per zone (average): min=0.0, max=171.0, var=285.57
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=285.85
# 📊 Vehicles per zone (average): min=0.0, max=175.25, var=290.35
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=287.12
# 📊 Vehicles per zone (average): min=0.0, max=174.75, var=287.46
# 📊 Vehicles per zone (average): min=0.0, max=171.0, var=281.34
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=280.81
# 📊 Vehicles per zone (average): min=0.0, max=177.75, var=297.22
# 📊 Vehicles per zone (average): min=0.0, max=175.5, var=284.07
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=280.96
# 📊 Vehicles per zone (average): min=0.0, max=169.75, var=281.46
#    📊 Evaluation summary:
#       Best objective: 272.7089
#       Worst objective: 305.7726
#       Average objective: 286.8381
#       Feasible solutions: 60/60
#     27 |     1620 |  0.03333 |       3 |  0.4210 |  1.92851 |  2.09236 |  0.000000E+00 |  0.000000E+00 |  2.835324E+02 |  2.727089E+02
# 📊 Vehicles per zone (average): min=0.0, max=178.75, var=298.38
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=285.32
# 📊 Vehicles per zone (average): min=0.0, max=170.25, var=279.50
# 📊 Vehicles per zone (average): min=0.0, max=176.75, var=303.01
# 📊 Vehicles per zone (average): min=0.0, max=176.0, var=288.18
# 📊 Vehicles per zone (average): min=0.0, max=178.25, var=294.06
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=283.89
# 📊 Vehicles per zone (average): min=0.0, max=178.0, var=290.47
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=302.48
# 📊 Vehicles per zone (average): min=0.0, max=179.25, var=300.84
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=283.24
# 📊 Vehicles per zone (average): min=0.0, max=177.0, var=294.78
# 📊 Vehicles per zone (average): min=0.0, max=175.5, var=293.96
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=295.36
# 📊 Vehicles per zone (average): min=0.0, max=168.25, var=272.71
# 📊 Vehicles per zone (average): min=0.0, max=169.0, var=274.44
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=303.37
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=279.15
# 📊 Vehicles per zone (average): min=0.0, max=171.0, var=282.18
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=292.46
# 📊 Vehicles per zone (average): min=0.0, max=176.5, var=294.39
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=295.84
# 📊 Vehicles per zone (average): min=0.0, max=177.0, var=294.68
# 📊 Vehicles per zone (average): min=0.0, max=174.0, var=286.23
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=286.77
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=284.00
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=286.06
# 📊 Vehicles per zone (average): min=0.0, max=174.25, var=297.99
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=283.17
# 📊 Calculating PT+DRT vehicles per zone... (eval #1650)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 9755.0
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=284.42
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=285.54
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=279.41
# 📊 Vehicles per zone (average): min=0.0, max=178.25, var=296.66
# 📊 Vehicles per zone (average): min=0.0, max=174.75, var=282.44
# 📊 Vehicles per zone (average): min=0.0, max=176.0, var=289.88
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=293.88
# 📊 Vehicles per zone (average): min=0.0, max=177.0, var=296.76
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=282.84
# 📊 Vehicles per zone (average): min=0.0, max=179.0, var=291.00
# 📊 Vehicles per zone (average): min=0.0, max=175.0, var=284.90
# 📊 Vehicles per zone (average): min=0.0, max=173.75, var=298.82
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=278.97
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=281.14
# 📊 Vehicles per zone (average): min=0.0, max=177.0, var=284.63
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=280.31
# 📊 Vehicles per zone (average): min=0.0, max=177.0, var=288.11
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=282.46
# 📊 Vehicles per zone (average): min=0.0, max=175.25, var=296.75
# 📊 Vehicles per zone (average): min=0.0, max=181.0, var=303.56
# 📊 Vehicles per zone (average): min=0.0, max=171.0, var=284.38
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=301.60
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=295.90
# 📊 Vehicles per zone (average): min=0.0, max=176.25, var=299.79
# 📊 Vehicles per zone (average): min=0.0, max=176.25, var=292.28
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=280.75
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=286.62
# 📊 Vehicles per zone (average): min=0.0, max=168.75, var=277.22
# 📊 Vehicles per zone (average): min=0.0, max=171.5, var=283.79
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=282.19
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=284.76
#    📊 Evaluation summary:
#       Best objective: 272.7089
#       Worst objective: 303.5557
#       Average objective: 288.9775
#       Feasible solutions: 60/60
#     28 |     1680 | -2.3E-02 |       3 |  0.3858 |  1.92045 |  2.10886 |  0.000000E+00 |  0.000000E+00 |  2.828804E+02 |  2.727089E+02
# 📊 Vehicles per zone (average): min=0.0, max=174.0, var=285.08
# 📊 Vehicles per zone (average): min=0.0, max=169.5, var=271.44
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=284.85
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=280.24
# 📊 Vehicles per zone (average): min=0.0, max=180.0, var=297.93
# 📊 Vehicles per zone (average): min=0.0, max=176.0, var=294.31
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=275.56
# 📊 Vehicles per zone (average): min=0.0, max=174.0, var=285.48
# 📊 Vehicles per zone (average): min=0.0, max=178.75, var=295.13
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=294.67
# 📊 Vehicles per zone (average): min=0.0, max=171.25, var=277.09
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=286.87
# 📊 Vehicles per zone (average): min=0.0, max=167.0, var=274.16
# 📊 Vehicles per zone (average): min=0.0, max=171.5, var=284.21
# 📊 Vehicles per zone (average): min=0.0, max=168.25, var=272.89
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=286.24
# 📊 Vehicles per zone (average): min=0.0, max=174.25, var=286.94
# 📊 Vehicles per zone (average): min=0.0, max=170.0, var=275.73
# 📊 Vehicles per zone (average): min=0.0, max=173.75, var=288.55
# 📊 Calculating PT+DRT vehicles per zone... (eval #1700)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 9786.0
# 📊 Vehicles per zone (average): min=0.0, max=175.25, var=292.72
# 📊 Vehicles per zone (average): min=0.0, max=171.25, var=277.34
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=283.31
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=284.69
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=285.65
# 📊 Vehicles per zone (average): min=0.0, max=181.0, var=297.20
# 📊 Vehicles per zone (average): min=0.0, max=171.25, var=281.71
# 📊 Vehicles per zone (average): min=0.0, max=178.0, var=294.65
# 📊 Vehicles per zone (average): min=0.0, max=171.25, var=278.31
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=292.33
# 📊 Vehicles per zone (average): min=0.0, max=176.0, var=293.08
# 📊 Vehicles per zone (average): min=0.0, max=176.5, var=298.51
# 📊 Vehicles per zone (average): min=0.0, max=173.75, var=286.56
# 📊 Vehicles per zone (average): min=0.0, max=176.0, var=292.86
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=278.26
# 📊 Vehicles per zone (average): min=0.0, max=175.25, var=294.04
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=283.86
# 📊 Vehicles per zone (average): min=0.0, max=175.5, var=291.64
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=286.53
# 📊 Vehicles per zone (average): min=0.0, max=177.25, var=302.38
# 📊 Vehicles per zone (average): min=0.0, max=174.0, var=284.73
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=286.09
# 📊 Vehicles per zone (average): min=0.0, max=169.25, var=276.88
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=282.27
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=293.04
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=282.96
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=278.01
# 📊 Vehicles per zone (average): min=0.0, max=170.0, var=284.61
# 📊 Vehicles per zone (average): min=0.0, max=171.0, var=279.65
# 📊 Vehicles per zone (average): min=0.0, max=174.25, var=284.22
# 📊 Vehicles per zone (average): min=0.0, max=171.0, var=280.96
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=284.58
# 📊 Vehicles per zone (average): min=0.0, max=177.0, var=291.08
# 📊 Vehicles per zone (average): min=0.0, max=176.5, var=286.28
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=284.37
# 📊 Vehicles per zone (average): min=0.0, max=171.75, var=280.44
# 📊 Vehicles per zone (average): min=0.0, max=176.75, var=297.41
# 📊 Vehicles per zone (average): min=0.0, max=168.5, var=269.34
# 📊 Vehicles per zone (average): min=0.0, max=174.0, var=285.82
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=293.83
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=290.02
#    📊 Evaluation summary:
#       Best objective: 269.3441
#       Worst objective: 302.3809
#       Average objective: 285.8266
#       Feasible solutions: 60/60
#     29 |     1740 | -2.6E-02 |       3 |  0.3837 |  1.90795 |  2.11513 |  0.000000E+00 |  0.000000E+00 |  2.812248E+02 |  2.693441E+02
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=280.14
# 📊 Vehicles per zone (average): min=0.0, max=169.5, var=276.88
# 📊 Vehicles per zone (average): min=0.0, max=170.75, var=280.92
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=278.43
# 📊 Vehicles per zone (average): min=0.0, max=174.25, var=304.74
# 📊 Vehicles per zone (average): min=0.0, max=180.0, var=296.34
# 📊 Vehicles per zone (average): min=0.0, max=168.0, var=266.98
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=276.66
# 📊 Vehicles per zone (average): min=0.0, max=174.75, var=282.20
# 📊 Calculating PT+DRT vehicles per zone... (eval #1750)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 9671.0
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=275.31
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=278.27
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=274.79
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=282.21
# 📊 Vehicles per zone (average): min=0.0, max=174.5, var=281.00
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=277.83
# 📊 Vehicles per zone (average): min=0.0, max=176.0, var=280.97
# 📊 Vehicles per zone (average): min=0.0, max=173.75, var=280.80
# 📊 Vehicles per zone (average): min=0.0, max=167.25, var=269.74
# 📊 Vehicles per zone (average): min=0.0, max=169.5, var=278.57
# 📊 Vehicles per zone (average): min=0.0, max=174.75, var=277.74
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=271.28
# 📊 Vehicles per zone (average): min=0.0, max=169.0, var=271.06
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=283.80
# 📊 Vehicles per zone (average): min=0.0, max=169.25, var=274.42
# 📊 Vehicles per zone (average): min=0.0, max=168.0, var=266.56
# 📊 Vehicles per zone (average): min=0.0, max=170.0, var=276.12
# 📊 Vehicles per zone (average): min=0.0, max=173.25, var=284.60
# 📊 Vehicles per zone (average): min=0.0, max=169.0, var=271.21
# 📊 Vehicles per zone (average): min=0.0, max=169.5, var=280.03
# 📊 Vehicles per zone (average): min=0.0, max=172.0, var=278.86
# 📊 Vehicles per zone (average): min=0.0, max=172.25, var=278.85
# 📊 Vehicles per zone (average): min=0.0, max=169.25, var=262.52
# 📊 Vehicles per zone (average): min=0.0, max=174.0, var=293.61
# 📊 Vehicles per zone (average): min=0.0, max=170.0, var=272.62
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=280.37
# 📊 Vehicles per zone (average): min=0.0, max=169.0, var=273.22
# 📊 Vehicles per zone (average): min=0.0, max=174.25, var=281.24
# 📊 Vehicles per zone (average): min=0.0, max=175.75, var=287.91
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=278.66
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=278.97
# 📊 Vehicles per zone (average): min=0.0, max=178.75, var=288.23
# 📊 Vehicles per zone (average): min=0.0, max=168.25, var=271.10
# 📊 Vehicles per zone (average): min=0.0, max=170.75, var=278.02
# 📊 Vehicles per zone (average): min=0.0, max=171.25, var=293.13
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=282.45
# 📊 Vehicles per zone (average): min=0.0, max=170.5, var=276.77
# 📊 Vehicles per zone (average): min=0.0, max=170.0, var=269.97
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=281.43
# 📊 Vehicles per zone (average): min=0.0, max=171.5, var=284.84
# 📊 Vehicles per zone (average): min=0.0, max=169.25, var=274.56
# 📊 Vehicles per zone (average): min=0.0, max=173.5, var=277.81
# 📊 Vehicles per zone (average): min=0.0, max=176.25, var=286.96
# 📊 Vehicles per zone (average): min=0.0, max=179.0, var=290.56
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=271.62
# 📊 Vehicles per zone (average): min=0.0, max=172.75, var=280.88
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=281.96
# 📊 Vehicles per zone (average): min=0.0, max=168.5, var=269.34
# 📊 Vehicles per zone (average): min=0.0, max=177.5, var=294.04
# 📊 Vehicles per zone (average): min=0.0, max=172.5, var=283.74
# 📊 Calculating PT+DRT vehicles per zone... (eval #1800)
# 🔍 System peak analysis:
#    Peak interval: 2 (12-18h)
#    Peak total vehicles: 9629.0
# 📊 Vehicles per zone (average): min=0.0, max=173.0, var=276.98
#    📊 Evaluation summary:
#       Best objective: 262.5206
#       Worst objective: 304.7395
#       Average objective: 279.3471
#       Feasible solutions: 60/60
#     30 |     1800 | -2.6E-02 |       3 |  0.3838 |  1.89942 |  2.13000 |  0.000000E+00 |  0.000000E+00 |  2.772591E+02 |  2.625206E+02
#
# ✅ OPTIMIZATION COMPLETED
#    Best objective: 262.520622
#    Generations: 30
#    Time: 24.1s
#    Avg time/gen: 0.802s
#    Best feasible solutions tracked: 3
#    ✅ All constraints satisfied
#
# ✅ OPTIMIZATION WITH SOLUTION LIST SEEDING COMPLETE:
#    Best objective: 262.520622
#    Runtime: 24.1s
#    Generations: 30
#    Feasible: True

# %% [markdown]
# ### Demonstration of Multi-PSO run with seeded population
#
# Parallel PSO runs are explained in `2c_optimization_multi_swarm.ipynb`. Here we just show how to run multiple PSO runs with seeded populations. The only difference is that the `sampling` config is passed to each PSO run.
#
# `TODO`: understand if random_seed should be used here or not. If used, the are our initial samples the same?

# %%
print("\n📚 MULTI-RUN OPTIMIZATION WITH SEEDING:")
print("   Each run gets a different random seed for perturbations")

# Multi-run configuration with seeding
config_multi_run_seeded = {
    'problem': {
        'objective': {
            'type': 'HexagonalCoverageObjective',
            'spatial_resolution_km': 2.0,
            'boundary': study_boundary,
            'crs': 'EPSG:3857',
            'time_aggregation': 'average'
        },
        'constraints': [
            {
                'type': 'FleetTotalConstraintHandler',
                'baseline': 'current_peak',
                'tolerance': 0.30,
                'measure': 'peak'
            }
        ]
    },
    'optimization': {
        'algorithm': {
            'type': 'PSO',
            'pop_size': 60,
            'inertia_weight': 0.9,
            'cognitive_coeff': 2.0,
            'social_coeff': 2.0,
            'adaptive': True
        },
        'sampling': {
            'enabled': True,
            'base_solutions': flat_solutions_from_files, #'from_data',
            'frac_gaussian_pert': 0.2,
            'gaussian_sigma': 1.5
            # Note: No random_seed, each run gets unique randomness
        },
        'termination': {
            'max_generations': 30  # Shorter for demo
        },
        'monitoring': {
            'progress_frequency': 5,
            'save_history': False
        }
    }
}

print("\n🚀 RUNNING 5 INDEPENDENT PSO RUNS WITH SEEDING:")
print("   Each run: 25 particles, 10 generations")
print("   Seeding: 70% Gaussian from base GTFS solution")
print("   Track top 2 solutions per run")

config_manager_multi = OptimizationConfigManager(config_dict=config_multi_run_seeded)
runner_multi = PSORunner(config_manager_multi)

multi_result_seeded = runner_multi.optimize_multi_run(
    optimization_data=opt_data,
    num_runs=3,
    parallel=True,
    track_best_n=2
)

print(f"\n✅ MULTI-RUN WITH SEEDING COMPLETE:")
print(f"   Best overall objective: {multi_result_seeded.best_result.best_objective:.6f}")
print(f"   Total time: {multi_result_seeded.total_time:.1f}s")
print(f"   Runs completed: {multi_result_seeded.num_runs_completed}")

# Per-run analysis
print(f"\n📊 PER-RUN RESULTS:")
print(f"   {'Run':<5} {'Objective':<12} {'Feasible':<9} {'Time(s)':<8} {'Solutions':<10}")
print(f"   {'-'*55}")
for summary in multi_result_seeded.run_summaries:
    print(f"   {summary['run_id']:<5} {summary['objective']:<12.6f} "
          f"{str(summary['feasible']):<9} {summary['time']:<8.1f} "
          f"{summary['best_feasible_solutions_count']:<10}")

# Statistical analysis
stats = multi_result_seeded.statistical_summary

print(f"\n📈 STATISTICAL ANALYSIS:")
print(f"   Mean objective: {stats['objective_mean']:.6f} ± {stats['objective_std']:.6f}")
print(f"   Best objective: {stats['objective_min']:.6f}")
# Out:
# 📚 MULTI-RUN OPTIMIZATION WITH SEEDING:
#    Each run gets a different random seed for perturbations
#
# 🚀 RUNNING 5 INDEPENDENT PSO RUNS WITH SEEDING:
#    Each run: 25 particles, 10 generations
#    Seeding: 70% Gaussian from base GTFS solution
#    Track top 2 solutions per run
# 📋 Using provided configuration dictionary
# 🔄 STARTING MULTI-RUN PSO OPTIMIZATION (3 runs)
#    🚀 Parallel execution enabled
# 🚀 PARALLEL EXECUTION:
#    👥 Using 3 parallel workers
#    🔇 Individual run output suppressed for clarity
#    📊 Progress will be shown as runs complete
#
# 📋 Using provided configuration dictionary
# 📋 Using provided configuration dictionary
# 📋 Using provided configuration dictionary
# [ 1/3] Run  1: Objective=320.054326, Gens=30, Time= 35.4s, FeasibleSols=2, ✅ Feasible
# [ 2/3] Run  2: Objective=273.864521, Gens=30, Time= 35.6s, FeasibleSols=2, ✅ Feasible
# [ 3/3] Run  3: Objective=316.412550, Gens=30, Time= 35.4s, FeasibleSols=2, ✅ Feasible
#
# ✅ All parallel runs completed!
#
# 🎯 MULTI-RUN OPTIMIZATION COMPLETED
#    Successful runs: 3/3
#    Total time: 40.3s
#    Best objective: 273.864521
#    Mean objective: 303.443799
#    Std objective: 20.968483
#    Total feasible solutions tracked: 6
#
# ✅ MULTI-RUN WITH SEEDING COMPLETE:
#    Best overall objective: 273.864521
#    Total time: 40.3s
#    Runs completed: 3
#
# 📊 PER-RUN RESULTS:
#    Run   Objective    Feasible  Time(s)  Solutions
#    -------------------------------------------------------
#    1     320.054326   True      35.4     2
#    2     273.864521   True      35.6     2
#    3     316.412550   True      35.4     2
#
# 📈 STATISTICAL ANALYSIS:
#    Mean objective: 303.443799 ± 20.968483
#    Best objective: 273.864521

# %% [markdown]
# # Comparing results
#
# We can compare whether seeding resulted in better solutions (better objective values) by looking at the best objectives found in each case.
#
# THIS IS JUST A DEMONSTATION AND THE RESULTS ARE NOT INDICATIVE - PSO NEEDS TO BE RUN WITH LARGER POPULATIONS AND MANY MORE GENERATIONS TO MAKE SUCH A COMPARISON

# %%
print(f"\n📊 COMPARING ALL RUNS TO BASELINE (NO SEEDING):")
print(" (Note: We aim to minimize the objective, so lower is better)")
print(f"   {'-'*60}")
print(f"   {'Strategy':<25} {'Objective':<12} {'Time(s)':<8} {'Improvement':<12}")
print(f"   {'-'*60}")

baseline_obj = result_baseline.best_objective

print(f"   {'Baseline (no seeding)':<25} {result_baseline.best_objective:<12.6f} "
        f"{result_baseline.optimization_time:<8.1f} {'--':<12}")

improvement_data = ((baseline_obj - result_from_data.best_objective) / baseline_obj * 100)
print(f"   {'From Data seeding':<25} {result_from_data.best_objective:<12.6f} "
        f"{result_from_data.optimization_time:<8.1f} {improvement_data:+.2f}%")

improvement_list = ((baseline_obj - result_from_list.best_objective) / baseline_obj * 100)
print(f"   {'Solution List seeding':<25} {result_from_list.best_objective:<12.6f} "
        f"{result_from_list.optimization_time:<8.1f} {improvement_list:+.2f}%")

improvement_multi = ((baseline_obj - stats['objective_min']) / baseline_obj * 100)
print(f"   {'Multi-Run seeding':<25} {stats['objective_min']:<12.6f} "
        f"{multi_result_seeded.total_time:<8.1f} {improvement_multi:+.2f}%")
# Out:
# 📊 COMPARING ALL RUNS TO BASELINE (NO SEEDING):
#  (Note: We aim to minimize the objective, so lower is better.)
#    ------------------------------------------------------------
#    Strategy                  Objective    Time(s)  Improvement
#    ------------------------------------------------------------
#    Baseline (no seeding)     387.895621   24.4     --
#    From Data seeding         377.338692   24.9     +2.72%
#    Solution List seeding     262.520622   24.1     +32.32%
#    Multi-Run seeding         273.864521   40.3     +29.40%
